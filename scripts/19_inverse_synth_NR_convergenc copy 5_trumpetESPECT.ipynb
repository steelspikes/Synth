# %%
import os

# Subir un nivel respecto a la carpeta actual
os.chdir("..")

import numpy as np
from globals import SAMPLE_RATE
import librosa
import matplotlib.pyplot as plt
from IPython.display import Audio, display

from Utils import from_matrix_to_preset, denormalize_preset, pretty_print, get_audio, split_audio
import numpy as np
import matplotlib.pyplot as plt
from Optimizers import search_with_DE, search_with_CMA, evaluate_target, render_presets

# %%
audio_path = 'C:/Users/bryan/Documents/GitHub/Synth/exports/Trumpet_target.wav'
audio = get_audio(audio_path)

plt.plot(audio)
plt.show()
Audio(audio, rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_segments = split_audio(audio, SAMPLE_RATE)

audio_segments = audio_segments[0:2]

for audio_segment in audio_segments:
    plt.plot(audio_segment)
    plt.show()
    display(Audio(audio_segment, rate=SAMPLE_RATE))

print('Pieces', len(audio_segments))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Pieces 1

# %%
estimated_presets = []
i = 1
last_best = None

if __name__ == '__main__':
    for audio_segment in audio_segments:
        print('Piece', i)
        target_C = evaluate_target(np.expand_dims(audio_segment, axis=0))
        duration = len(audio_segment) / SAMPLE_RATE
        if last_best is None:
            best, episodes_de = search_with_DE(target_C, duration, disp=True, maxiter=200)
            best, episodes_cma = search_with_CMA(target_C, duration, best)
            print(episodes_de, episodes_cma)
        else:
            best, _ = search_with_CMA(target_C, duration, last_best)

        last_best = best
        estimated_presets.append((best, duration))
        i+=1

        plt.plot(episodes_de, label='DE')
        plt.legend()
        plt.show()
        plt.plot(episodes_cma, label='CMA')
        plt.legend()
        plt.show()
# Out:
# Piece 1
# c:\Users\bryan\Documents\GitHub\Synth\venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:487: UserWarning: differential_evolution: the 'vectorized' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# differential_evolution step 1: f(x)= 0.06109056147902597
# differential_evolution step 2: f(x)= 0.06109056147902597
# differential_evolution step 3: f(x)= 0.06109056147902597
# differential_evolution step 4: f(x)= 0.06109056147902597
# differential_evolution step 5: f(x)= 0.06109056147902597
# differential_evolution step 6: f(x)= 0.06109056147902597
# differential_evolution step 7: f(x)= 0.058224960437782684
# differential_evolution step 8: f(x)= 0.058224960437782684
# differential_evolution step 9: f(x)= 0.058224960437782684
# differential_evolution step 10: f(x)= 0.058224960437782684
# differential_evolution step 11: f(x)= 0.058224960437782684
# differential_evolution step 12: f(x)= 0.058224960437782684
# differential_evolution step 13: f(x)= 0.0557036951089651
# differential_evolution step 14: f(x)= 0.0557036951089651
# differential_evolution step 15: f(x)= 0.0557036951089651
# differential_evolution step 16: f(x)= 0.0557036951089651
# differential_evolution step 17: f(x)= 0.0557036951089651
# differential_evolution step 18: f(x)= 0.0557036951089651
# differential_evolution step 19: f(x)= 0.0557036951089651
# differential_evolution step 20: f(x)= 0.0557036951089651
# differential_evolution step 21: f(x)= 0.0557036951089651
# differential_evolution step 22: f(x)= 0.0557036951089651
# differential_evolution step 23: f(x)= 0.0557036951089651
# differential_evolution step 24: f(x)= 0.0557036951089651
# differential_evolution step 25: f(x)= 0.0557036951089651
# differential_evolution step 26: f(x)= 0.0557036951089651
# differential_evolution step 27: f(x)= 0.0557036951089651
# differential_evolution step 28: f(x)= 0.0557036951089651
# differential_evolution step 29: f(x)= 0.0557036951089651
# differential_evolution step 30: f(x)= 0.0557036951089651
# differential_evolution step 31: f(x)= 0.0557036951089651
# differential_evolution step 32: f(x)= 0.0557036951089651
# differential_evolution step 33: f(x)= 0.0557036951089651
# differential_evolution step 34: f(x)= 0.0557036951089651
# differential_evolution step 35: f(x)= 0.0557036951089651
# differential_evolution step 36: f(x)= 0.0557036951089651
# differential_evolution step 37: f(x)= 0.0557036951089651
# differential_evolution step 38: f(x)= 0.0557036951089651
# differential_evolution step 39: f(x)= 0.0557036951089651
# differential_evolution step 40: f(x)= 0.051497573110682565
# differential_evolution step 41: f(x)= 0.051497573110682565
# differential_evolution step 42: f(x)= 0.051497573110682565
# differential_evolution step 43: f(x)= 0.051497573110682565
# differential_evolution step 44: f(x)= 0.051497573110682565
# differential_evolution step 45: f(x)= 0.051497573110682565
# differential_evolution step 46: f(x)= 0.051497573110682565
# differential_evolution step 47: f(x)= 0.051497573110682565
# differential_evolution step 48: f(x)= 0.051497573110682565
# differential_evolution step 49: f(x)= 0.051497573110682565
# differential_evolution step 50: f(x)= 0.051497573110682565
# differential_evolution step 51: f(x)= 0.051497573110682565
# differential_evolution step 52: f(x)= 0.051497573110682565
# differential_evolution step 53: f(x)= 0.051497573110682565
# differential_evolution step 54: f(x)= 0.051497573110682565
# differential_evolution step 55: f(x)= 0.051497573110682565
# differential_evolution step 56: f(x)= 0.051497573110682565
# differential_evolution step 57: f(x)= 0.051497573110682565
# differential_evolution step 58: f(x)= 0.051497573110682565
# differential_evolution step 59: f(x)= 0.051497573110682565
# differential_evolution step 60: f(x)= 0.051497573110682565
# differential_evolution step 61: f(x)= 0.051497573110682565
# differential_evolution step 62: f(x)= 0.051497573110682565
# differential_evolution step 63: f(x)= 0.051497573110682565
# differential_evolution step 64: f(x)= 0.051497573110682565
# differential_evolution step 65: f(x)= 0.051497573110682565
# differential_evolution step 66: f(x)= 0.051497573110682565
# differential_evolution step 67: f(x)= 0.051497573110682565
# differential_evolution step 68: f(x)= 0.051497573110682565
# differential_evolution step 69: f(x)= 0.051497573110682565
# differential_evolution step 70: f(x)= 0.051497573110682565
# differential_evolution step 71: f(x)= 0.051497573110682565
# differential_evolution step 72: f(x)= 0.051497573110682565
# differential_evolution step 73: f(x)= 0.051497573110682565
# differential_evolution step 74: f(x)= 0.051497573110682565
# differential_evolution step 75: f(x)= 0.051497573110682565
# differential_evolution step 76: f(x)= 0.051497573110682565
# differential_evolution step 77: f(x)= 0.051497573110682565
# differential_evolution step 78: f(x)= 0.051497573110682565
# differential_evolution step 79: f(x)= 0.051497573110682565
# differential_evolution step 80: f(x)= 0.051497573110682565
# differential_evolution step 81: f(x)= 0.051497573110682565
# differential_evolution step 82: f(x)= 0.051497573110682565
# differential_evolution step 83: f(x)= 0.051497573110682565
# differential_evolution step 84: f(x)= 0.051497573110682565
# differential_evolution step 85: f(x)= 0.051497573110682565
# differential_evolution step 86: f(x)= 0.051497573110682565
# differential_evolution step 87: f(x)= 0.051497573110682565
# differential_evolution step 88: f(x)= 0.051497573110682565
# differential_evolution step 89: f(x)= 0.051497573110682565
# differential_evolution step 90: f(x)= 0.051497573110682565
# differential_evolution step 91: f(x)= 0.051497573110682565
# differential_evolution step 92: f(x)= 0.051497573110682565
# differential_evolution step 93: f(x)= 0.051497573110682565
# differential_evolution step 94: f(x)= 0.051497573110682565
# differential_evolution step 95: f(x)= 0.051497573110682565
# differential_evolution step 96: f(x)= 0.051497573110682565
# differential_evolution step 97: f(x)= 0.051497573110682565
# differential_evolution step 98: f(x)= 0.051497573110682565
# differential_evolution step 99: f(x)= 0.051497573110682565
# differential_evolution step 100: f(x)= 0.051497573110682565
# differential_evolution step 101: f(x)= 0.051497573110682565
# differential_evolution step 102: f(x)= 0.051497573110682565
# differential_evolution step 103: f(x)= 0.051497573110682565
# differential_evolution step 104: f(x)= 0.051497573110682565
# differential_evolution step 105: f(x)= 0.051497573110682565
# differential_evolution step 106: f(x)= 0.051497573110682565
# differential_evolution step 107: f(x)= 0.051497573110682565
# differential_evolution step 108: f(x)= 0.051497573110682565
# differential_evolution step 109: f(x)= 0.051497573110682565
# differential_evolution step 110: f(x)= 0.051497573110682565
# differential_evolution step 111: f(x)= 0.051497573110682565
# differential_evolution step 112: f(x)= 0.051497573110682565
# differential_evolution step 113: f(x)= 0.051497573110682565
# differential_evolution step 114: f(x)= 0.051497573110682565
# differential_evolution step 115: f(x)= 0.051497573110682565
# differential_evolution step 116: f(x)= 0.051497573110682565
# differential_evolution step 117: f(x)= 0.051497573110682565
# differential_evolution step 118: f(x)= 0.051497573110682565
# differential_evolution step 119: f(x)= 0.051497573110682565
# differential_evolution step 120: f(x)= 0.051497573110682565
# differential_evolution step 121: f(x)= 0.051497573110682565
# differential_evolution step 122: f(x)= 0.051497573110682565
# differential_evolution step 123: f(x)= 0.051497573110682565
# differential_evolution step 124: f(x)= 0.051497573110682565
# differential_evolution step 125: f(x)= 0.051497573110682565
# differential_evolution step 126: f(x)= 0.051497573110682565
# differential_evolution step 127: f(x)= 0.051497573110682565
# differential_evolution step 128: f(x)= 0.051497573110682565
# differential_evolution step 129: f(x)= 0.051497573110682565
# differential_evolution step 130: f(x)= 0.051497573110682565
# differential_evolution step 131: f(x)= 0.051497573110682565
# differential_evolution step 132: f(x)= 0.051497573110682565
# differential_evolution step 133: f(x)= 0.051497573110682565
# differential_evolution step 134: f(x)= 0.051497573110682565
# differential_evolution step 135: f(x)= 0.051497573110682565
# differential_evolution step 136: f(x)= 0.051497573110682565
# differential_evolution step 137: f(x)= 0.051497573110682565
# differential_evolution step 138: f(x)= 0.051497573110682565
# differential_evolution step 139: f(x)= 0.05133250074019256
# differential_evolution step 140: f(x)= 0.05133250074019256
# differential_evolution step 141: f(x)= 0.05133250074019256
# differential_evolution step 142: f(x)= 0.05133250074019256
# differential_evolution step 143: f(x)= 0.05133250074019256
# differential_evolution step 144: f(x)= 0.05133250074019256
# differential_evolution step 145: f(x)= 0.05133250074019256
# differential_evolution step 146: f(x)= 0.05133250074019256
# differential_evolution step 147: f(x)= 0.05133250074019256
# differential_evolution step 148: f(x)= 0.05133250074019256
# differential_evolution step 149: f(x)= 0.05133250074019256
# differential_evolution step 150: f(x)= 0.05133250074019256
# differential_evolution step 151: f(x)= 0.05133250074019256
# differential_evolution step 152: f(x)= 0.05133250074019256
# differential_evolution step 153: f(x)= 0.05133250074019256
# differential_evolution step 154: f(x)= 0.05133250074019256
# differential_evolution step 155: f(x)= 0.05133250074019256
# differential_evolution step 156: f(x)= 0.05133250074019256
# differential_evolution step 157: f(x)= 0.05133250074019256
# differential_evolution step 158: f(x)= 0.05133250074019256
# differential_evolution step 159: f(x)= 0.05133250074019256
# differential_evolution step 160: f(x)= 0.05133250074019256
# differential_evolution step 161: f(x)= 0.05133250074019256
# differential_evolution step 162: f(x)= 0.05133250074019256
# differential_evolution step 163: f(x)= 0.05133250074019256
# differential_evolution step 164: f(x)= 0.05133250074019256
# differential_evolution step 165: f(x)= 0.05133250074019256
# differential_evolution step 166: f(x)= 0.05133250074019256
# differential_evolution step 167: f(x)= 0.05133250074019256
# differential_evolution step 168: f(x)= 0.05133250074019256
# differential_evolution step 169: f(x)= 0.05133250074019256
# differential_evolution step 170: f(x)= 0.05133250074019256
# differential_evolution step 171: f(x)= 0.05133250074019256
# differential_evolution step 172: f(x)= 0.05133250074019256
# differential_evolution step 173: f(x)= 0.05133250074019256
# differential_evolution step 174: f(x)= 0.05133250074019256
# differential_evolution step 175: f(x)= 0.05133250074019256
# differential_evolution step 176: f(x)= 0.05133250074019256
# differential_evolution step 177: f(x)= 0.05133250074019256
# differential_evolution step 178: f(x)= 0.05133250074019256
# differential_evolution step 179: f(x)= 0.05133250074019256
# differential_evolution step 180: f(x)= 0.05133250074019256
# differential_evolution step 181: f(x)= 0.05133250074019256
# differential_evolution step 182: f(x)= 0.05133250074019256
# differential_evolution step 183: f(x)= 0.05133250074019256
# differential_evolution step 184: f(x)= 0.05133250074019256
# differential_evolution step 185: f(x)= 0.05133250074019256
# differential_evolution step 186: f(x)= 0.05133250074019256
# differential_evolution step 187: f(x)= 0.05133250074019256
# differential_evolution step 188: f(x)= 0.05133250074019256
# differential_evolution step 189: f(x)= 0.05133250074019256
# differential_evolution step 190: f(x)= 0.05133250074019256
# differential_evolution step 191: f(x)= 0.05133250074019256
# differential_evolution step 192: f(x)= 0.05133250074019256
# differential_evolution step 193: f(x)= 0.05133250074019256
# differential_evolution step 194: f(x)= 0.05133250074019256
# differential_evolution step 195: f(x)= 0.05133250074019256
# differential_evolution step 196: f(x)= 0.05133250074019256
# differential_evolution step 197: f(x)= 0.05133250074019256
# differential_evolution step 198: f(x)= 0.05133250074019256
# differential_evolution step 199: f(x)= 0.05133250074019256
# differential_evolution step 200: f(x)= 0.05133250074019256
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=1003020, Sun May  3 15:39:17 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=968919, Sun May  3 15:43:03 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=1030090, Sun May  3 15:46:50 2026)
# [np.float64(0.06167707079915024), np.float64(0.06104030964937555), np.float64(0.06019029611363033), np.float64(0.06079268470755305), np.float64(0.06080662001924474), np.float64(0.061326417103367635), np.float64(0.06459736023080312), np.float64(0.0731078726832041), np.float64(0.06743174836465939), np.float64(0.06435101943890234), np.float64(0.06906226743559221), np.float64(0.07101839730348673), np.float64(0.05641434102842522), np.float64(0.052813363554521764), np.float64(0.05766146398914119), np.float64(0.060155593129348324), np.float64(0.054667613776806526), np.float64(0.05777876443476592), np.float64(0.05938130160869761), np.float64(0.05651579303108047), np.float64(0.056748812410366625), np.float64(0.056580689401974284), np.float64(0.05290442489576281), np.float64(0.05964438339217962), np.float64(0.059576975463711206), np.float64(0.05551827813087102), np.float64(0.05230989298923879), np.float64(0.055469691643372086), np.float64(0.057589773197375016), np.float64(0.05634871011935432), np.float64(0.0526305586866289), np.float64(0.05815584699827692), np.float64(0.05619315797356313), np.float64(0.056086032947476015), np.float64(0.0561464865224376), np.float64(0.055350813864376465), np.float64(0.05313096838995137), np.float64(0.05519638485153299), np.float64(0.05886518095522323), np.float64(0.05246860981154969), np.float64(0.05210525514773301), np.float64(0.05161617937072993), np.float64(0.05234918870788634), np.float64(0.051368980797847345), np.float64(0.052484121913831644), np.float64(0.05137887387263823), np.float64(0.052077041525761224), np.float64(0.051420195870804035), np.float64(0.05136400878059697), np.float64(0.05225000848795236), np.float64(0.05192749316891193), np.float64(0.05236589478495659), np.float64(0.05191706611544977), np.float64(0.0528240121985483), np.float64(0.05253251547751018), np.float64(0.05198434046813689), np.float64(0.05133982998425536), np.float64(0.051935123787787335), np.float64(0.05182126803016557), np.float64(0.05189363490210997), np.float64(0.051717819409440195), np.float64(0.0519946413878729), np.float64(0.051788537452070335), np.float64(0.05105889389770407), np.float64(0.05205044005078331), np.float64(0.05229938356660181), np.float64(0.051888864374820425), np.float64(0.05164063001110412), np.float64(0.052411619910563645), np.float64(0.052910545947461654), np.float64(0.05099404969896114), np.float64(0.051568490884828275), np.float64(0.05203827857375628), np.float64(0.05233098935960708), np.float64(0.05188867405871953), np.float64(0.05203861606654595), np.float64(0.051702406264060356), np.float64(0.052174920741296635), np.float64(0.05246550158083982), np.float64(0.051122850790515095), np.float64(0.05192306392553437), np.float64(0.051679030703069055), np.float64(0.051461770281596965), np.float64(0.05172337373203253), np.float64(0.051804601209633164), np.float64(0.05121969758663185), np.float64(0.05165376437110999), np.float64(0.05245866528884436), np.float64(0.05229917876292907), np.float64(0.051068537774296666), np.float64(0.05159618549874531), np.float64(0.05092463473846503), np.float64(0.05131352229691571), np.float64(0.051375212299578636), np.float64(0.052294849277924126), np.float64(0.05240188338397052), np.float64(0.05183127737467849), np.float64(0.05313379512993021), np.float64(0.05207332220558731), np.float64(0.050879772544500934), np.float64(0.05271420265939743), np.float64(0.052454651528874165), np.float64(0.05237275628117836), np.float64(0.05141353433954305), np.float64(0.05268512864377245), np.float64(0.05215285201503646), np.float64(0.052062467121009266), np.float64(0.05183686787321936), np.float64(0.052525341079716036), np.float64(0.05161827751605674), np.float64(0.05119907254742076), np.float64(0.05184499435412433), np.float64(0.05255453890920791), np.float64(0.05131000315493633), np.float64(0.05204191692033339), np.float64(0.051260104580476765), np.float64(0.05115378078603067), np.float64(0.05279681408354686), np.float64(0.05147519507519739), np.float64(0.05126501130958625), np.float ...

# %%
predicted_joined_audio = []

for preset, duration in estimated_presets:
    preset = np.expand_dims(preset, axis=0)
    # error = evaluate_presets((denormalize_preset(from_matrix_to_preset(preset)), target_C, duration))
    # print('Error', error)
    # target_audio = np.expand_dims(audio_segments[0], axis=0)
    predicted_audio = render_presets(denormalize_preset(from_matrix_to_preset(preset)), duration)
    predicted_joined_audio.append(predicted_audio[0])

    denormalized_predicted_preset = denormalize_preset(from_matrix_to_preset(preset))
    pretty_print(denormalized_predicted_preset)

predicted_joined_audio = np.concatenate(predicted_joined_audio, axis=0)

print(min(episodes_cma))
# Out:
# {
#   osc1_shape:   [
#     0.2236979658815998
#   ]
#   osc1_phase:   [
#     0.8381536613997074
#   ]
#   osc1_volume:   [
#     0.999114776848685
#   ]
#   osc1_freq:   [
#     1165.4077070144951
#   ]
#   osc2_shape:   [
#     1.9677389515359756
#   ]
#   osc2_phase:   [
#     0.40481926976121574
#   ]
#   osc2_volume:   [
#     0.12356150765864604
#   ]
#   osc2_freq:   [
#     23.948742164195114
#   ]
#   osc3_shape:   [
#     0.7100701485942779
#   ]
#   osc3_phase:   [
#     0.6211570804956937
#   ]
#   osc3_volume:   [
#     0.5906069444235155
#   ]
#   osc3_freq:   [
#     691.7769628366416
#   ]
#   osc4_shape:   [
#     2.8775307170274895
#   ]
#   osc4_phase:   [
#     0.7554093350487832
#   ]
#   osc4_volume:   [
#     0.64885875419879
#   ]
#   osc4_freq:   [
#     23.84282958303319
#   ]
#   oscnoise_volume:   [
#     0.05593293662885096
#   ]
#   filter_envelope_attack:   [
#     0.4146809073697814
#   ]
#   filter_envelope_decay:   [
#     0.559245623937969
#   ]
#   filter_envelope_sustain:   [
#     0.3908048648047975
#   ]
#   filter_envelope_release:   [
#     0.14124340593314227
#   ]
#   base_cutoff_hz:   [
#     347.2008987423672
#   ]
#   filter_type:   [
#     0.9937694243014925
#   ]
#   base_q:   [
#     5.922521143518221
#   ]
#   envelope_depth:   [
#     0.27211568104304307
#   ]
#   envelope_attack:   [
#     0.08540570621518129
#   ]
#   envelope_decay:   [
#     0.0005899982640631987
#   ]
#   envelope_sustain:   [
#     0.2483526907068193
#   ]
#   envelope_release:   [
#     0.1281975538766633
#   ]
# }
# 0.043098871655729315

# %%
spect = evaluate_target(np.array([audio[:120000]]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(audio[:120000], rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from Utils import mel_spectrogram
def evaluate_target(audio):
    return mel_spectrogram(audio, sr=SAMPLE_RATE, n_fft=2048, hop_length=256)

spect = evaluate_target(np.array([predicted_joined_audio]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(predicted_joined_audio, rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
