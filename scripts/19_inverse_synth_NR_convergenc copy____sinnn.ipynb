# %%
import os

# Subir un nivel respecto a la carpeta actual
os.chdir("..")

import numpy as np
from globals import SAMPLE_RATE
import librosa
import matplotlib.pyplot as plt
from IPython.display import Audio, display

from Utils import from_matrix_to_preset, denormalize_preset, pretty_print, get_audio, split_audio
import numpy as np
import matplotlib.pyplot as plt
from Optimizers import search_with_DE, search_with_CMA, evaluate_target, render_presets

# %%
audio_path = 'C:/Users/bryan/Documents/GitHub/Synth/exports/s1_a4_target.wav'
audio = get_audio(audio_path)[:int(SAMPLE_RATE/2)]

plt.plot(audio)
plt.show()
Audio(audio, rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_segments = split_audio(audio, prominence=0.06)

audio_segments = audio_segments[0:2]

for audio_segment in audio_segments:
    plt.plot(audio_segment)
    plt.show()
    display(Audio(audio_segment, rate=SAMPLE_RATE))

print('Pieces', len(audio_segments))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Pieces 1

# %%
estimated_presets = []
i = 1
last_best = None

if __name__ == '__main__':
    for audio_segment in audio_segments:
        print('Piece', i)
        target_C = evaluate_target(np.expand_dims(audio_segment, axis=0))
        duration = len(audio_segment) / SAMPLE_RATE
        if last_best is None:
            best, episodes_de = search_with_DE(target_C, duration, disp=True, maxiter=200)
            best, episodes_cma = search_with_CMA(target_C, duration, best)
            print(episodes_de, episodes_cma)
        else:
            best, _ = search_with_CMA(target_C, duration, last_best)

        last_best = best
        estimated_presets.append((best, duration))
        i+=1

        plt.plot(episodes_de, label='DE')
        plt.legend()
        plt.show()
        plt.plot(episodes_cma, label='CMA')
        plt.legend()
        plt.show()
# Out:
# Piece 1
# c:\Users\bryan\Documents\GitHub\Synth\venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:487: UserWarning: differential_evolution: the 'vectorized' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# differential_evolution step 1: f(x)= 0.17388014218063633
# differential_evolution step 2: f(x)= 0.17388014218063633
# differential_evolution step 3: f(x)= 0.16887310612319162
# differential_evolution step 4: f(x)= 0.16887310612319162
# differential_evolution step 5: f(x)= 0.16887310612319162
# differential_evolution step 6: f(x)= 0.16887310612319162
# differential_evolution step 7: f(x)= 0.16887310612319162
# differential_evolution step 8: f(x)= 0.16887310612319162
# differential_evolution step 9: f(x)= 0.16887310612319162
# differential_evolution step 10: f(x)= 0.16887310612319162
# differential_evolution step 11: f(x)= 0.16887310612319162
# differential_evolution step 12: f(x)= 0.16887310612319162
# differential_evolution step 13: f(x)= 0.16887310612319162
# differential_evolution step 14: f(x)= 0.16887310612319162
# differential_evolution step 15: f(x)= 0.16887310612319162
# differential_evolution step 16: f(x)= 0.16887310612319162
# differential_evolution step 17: f(x)= 0.16887310612319162
# differential_evolution step 18: f(x)= 0.16887310612319162
# differential_evolution step 19: f(x)= 0.16887310612319162
# differential_evolution step 20: f(x)= 0.1670170858987873
# differential_evolution step 21: f(x)= 0.1670170858987873
# differential_evolution step 22: f(x)= 0.16634160566705655
# differential_evolution step 23: f(x)= 0.16634160566705655
# differential_evolution step 24: f(x)= 0.16634160566705655
# differential_evolution step 25: f(x)= 0.16634160566705655
# differential_evolution step 26: f(x)= 0.16634160566705655
# differential_evolution step 27: f(x)= 0.16634160566705655
# differential_evolution step 28: f(x)= 0.16634160566705655
# differential_evolution step 29: f(x)= 0.16634160566705655
# differential_evolution step 30: f(x)= 0.16634160566705655
# differential_evolution step 31: f(x)= 0.16495223206311438
# differential_evolution step 32: f(x)= 0.16495223206311438
# differential_evolution step 33: f(x)= 0.15922664389384186
# differential_evolution step 34: f(x)= 0.15922664389384186
# differential_evolution step 35: f(x)= 0.15922664389384186
# differential_evolution step 36: f(x)= 0.15922664389384186
# differential_evolution step 37: f(x)= 0.15922664389384186
# differential_evolution step 38: f(x)= 0.15922664389384186
# differential_evolution step 39: f(x)= 0.15922664389384186
# differential_evolution step 40: f(x)= 0.15922664389384186
# differential_evolution step 41: f(x)= 0.15922664389384186
# differential_evolution step 42: f(x)= 0.15922664389384186
# differential_evolution step 43: f(x)= 0.15922664389384186
# differential_evolution step 44: f(x)= 0.15922664389384186
# differential_evolution step 45: f(x)= 0.15922664389384186
# differential_evolution step 46: f(x)= 0.15922664389384186
# differential_evolution step 47: f(x)= 0.15922664389384186
# differential_evolution step 48: f(x)= 0.15922664389384186
# differential_evolution step 49: f(x)= 0.15922664389384186
# differential_evolution step 50: f(x)= 0.15922664389384186
# differential_evolution step 51: f(x)= 0.15922664389384186
# differential_evolution step 52: f(x)= 0.15922664389384186
# differential_evolution step 53: f(x)= 0.15922664389384186
# differential_evolution step 54: f(x)= 0.15922664389384186
# differential_evolution step 55: f(x)= 0.15922664389384186
# differential_evolution step 56: f(x)= 0.15922664389384186
# differential_evolution step 57: f(x)= 0.15922664389384186
# differential_evolution step 58: f(x)= 0.15922664389384186
# differential_evolution step 59: f(x)= 0.15922664389384186
# differential_evolution step 60: f(x)= 0.15922664389384186
# differential_evolution step 61: f(x)= 0.15922664389384186
# differential_evolution step 62: f(x)= 0.15922664389384186
# differential_evolution step 63: f(x)= 0.15922664389384186
# differential_evolution step 64: f(x)= 0.15922664389384186
# differential_evolution step 65: f(x)= 0.15922664389384186
# differential_evolution step 66: f(x)= 0.15922664389384186
# differential_evolution step 67: f(x)= 0.15922664389384186
# differential_evolution step 68: f(x)= 0.15922664389384186
# differential_evolution step 69: f(x)= 0.1578816221537254
# differential_evolution step 70: f(x)= 0.1578816221537254
# differential_evolution step 71: f(x)= 0.1578816221537254
# differential_evolution step 72: f(x)= 0.1578816221537254
# differential_evolution step 73: f(x)= 0.1578816221537254
# differential_evolution step 74: f(x)= 0.1578816221537254
# differential_evolution step 75: f(x)= 0.1578816221537254
# differential_evolution step 76: f(x)= 0.1578816221537254
# differential_evolution step 77: f(x)= 0.1578816221537254
# differential_evolution step 78: f(x)= 0.1578816221537254
# differential_evolution step 79: f(x)= 0.1578816221537254
# differential_evolution step 80: f(x)= 0.1578816221537254
# differential_evolution step 81: f(x)= 0.1578816221537254
# differential_evolution step 82: f(x)= 0.1578816221537254
# differential_evolution step 83: f(x)= 0.1578816221537254
# differential_evolution step 84: f(x)= 0.1578816221537254
# differential_evolution step 85: f(x)= 0.1578816221537254
# differential_evolution step 86: f(x)= 0.1578816221537254
# differential_evolution step 87: f(x)= 0.1578816221537254
# differential_evolution step 88: f(x)= 0.1578816221537254
# differential_evolution step 89: f(x)= 0.1578816221537254
# differential_evolution step 90: f(x)= 0.1578816221537254
# differential_evolution step 91: f(x)= 0.1578816221537254
# differential_evolution step 92: f(x)= 0.1578816221537254
# differential_evolution step 93: f(x)= 0.1578816221537254
# differential_evolution step 94: f(x)= 0.1578816221537254
# differential_evolution step 95: f(x)= 0.1578816221537254
# differential_evolution step 96: f(x)= 0.1578816221537254
# differential_evolution step 97: f(x)= 0.1578816221537254
# differential_evolution step 98: f(x)= 0.1578816221537254
# differential_evolution step 99: f(x)= 0.1578816221537254
# differential_evolution step 100: f(x)= 0.1578816221537254
# differential_evolution step 101: f(x)= 0.1578816221537254
# differential_evolution step 102: f(x)= 0.1578816221537254
# differential_evolution step 103: f(x)= 0.1578816221537254
# differential_evolution step 104: f(x)= 0.1578816221537254
# differential_evolution step 105: f(x)= 0.1578816221537254
# differential_evolution step 106: f(x)= 0.1578816221537254
# differential_evolution step 107: f(x)= 0.1578816221537254
# differential_evolution step 108: f(x)= 0.1578816221537254
# differential_evolution step 109: f(x)= 0.1578816221537254
# differential_evolution step 110: f(x)= 0.1578816221537254
# differential_evolution step 111: f(x)= 0.1578816221537254
# differential_evolution step 112: f(x)= 0.1578816221537254
# differential_evolution step 113: f(x)= 0.1578816221537254
# differential_evolution step 114: f(x)= 0.1578816221537254
# differential_evolution step 115: f(x)= 0.1578816221537254
# differential_evolution step 116: f(x)= 0.1578816221537254
# differential_evolution step 117: f(x)= 0.1578816221537254
# differential_evolution step 118: f(x)= 0.1578816221537254
# differential_evolution step 119: f(x)= 0.1578816221537254
# differential_evolution step 120: f(x)= 0.1578816221537254
# differential_evolution step 121: f(x)= 0.1578816221537254
# differential_evolution step 122: f(x)= 0.1578816221537254
# differential_evolution step 123: f(x)= 0.1578816221537254
# differential_evolution step 124: f(x)= 0.1578816221537254
# differential_evolution step 125: f(x)= 0.1578816221537254
# differential_evolution step 126: f(x)= 0.1578816221537254
# differential_evolution step 127: f(x)= 0.1578816221537254
# differential_evolution step 128: f(x)= 0.1578816221537254
# differential_evolution step 129: f(x)= 0.1578816221537254
# differential_evolution step 130: f(x)= 0.1578816221537254
# differential_evolution step 131: f(x)= 0.1578816221537254
# differential_evolution step 132: f(x)= 0.15509045033204855
# differential_evolution step 133: f(x)= 0.15509045033204855
# differential_evolution step 134: f(x)= 0.15509045033204855
# differential_evolution step 135: f(x)= 0.15509045033204855
# differential_evolution step 136: f(x)= 0.15509045033204855
# differential_evolution step 137: f(x)= 0.15509045033204855
# differential_evolution step 138: f(x)= 0.15509045033204855
# differential_evolution step 139: f(x)= 0.15509045033204855
# differential_evolution step 140: f(x)= 0.15509045033204855
# differential_evolution step 141: f(x)= 0.15509045033204855
# differential_evolution step 142: f(x)= 0.15509045033204855
# differential_evolution step 143: f(x)= 0.15509045033204855
# differential_evolution step 144: f(x)= 0.15509045033204855
# differential_evolution step 145: f(x)= 0.15509045033204855
# differential_evolution step 146: f(x)= 0.15509045033204855
# differential_evolution step 147: f(x)= 0.15509045033204855
# differential_evolution step 148: f(x)= 0.15509045033204855
# differential_evolution step 149: f(x)= 0.15509045033204855
# differential_evolution step 150: f(x)= 0.15509045033204855
# differential_evolution step 151: f(x)= 0.15509045033204855
# differential_evolution step 152: f(x)= 0.15509045033204855
# differential_evolution step 153: f(x)= 0.15509045033204855
# differential_evolution step 154: f(x)= 0.15509045033204855
# differential_evolution step 155: f(x)= 0.15509045033204855
# differential_evolution step 156: f(x)= 0.15509045033204855
# differential_evolution step 157: f(x)= 0.15509045033204855
# differential_evolution step 158: f(x)= 0.15509045033204855
# differential_evolution step 159: f(x)= 0.15509045033204855
# differential_evolution step 160: f(x)= 0.15509045033204855
# differential_evolution step 161: f(x)= 0.15509045033204855
# differential_evolution step 162: f(x)= 0.15509045033204855
# differential_evolution step 163: f(x)= 0.15509045033204855
# differential_evolution step 164: f(x)= 0.15509045033204855
# differential_evolution step 165: f(x)= 0.15509045033204855
# differential_evolution step 166: f(x)= 0.15509045033204855
# differential_evolution step 167: f(x)= 0.15509045033204855
# differential_evolution step 168: f(x)= 0.15509045033204855
# differential_evolution step 169: f(x)= 0.15509045033204855
# differential_evolution step 170: f(x)= 0.15509045033204855
# differential_evolution step 171: f(x)= 0.15509045033204855
# differential_evolution step 172: f(x)= 0.15509045033204855
# differential_evolution step 173: f(x)= 0.15509045033204855
# differential_evolution step 174: f(x)= 0.15509045033204855
# differential_evolution step 175: f(x)= 0.15509045033204855
# differential_evolution step 176: f(x)= 0.15509045033204855
# differential_evolution step 177: f(x)= 0.15509045033204855
# differential_evolution step 178: f(x)= 0.15509045033204855
# differential_evolution step 179: f(x)= 0.15509045033204855
# differential_evolution step 180: f(x)= 0.15509045033204855
# differential_evolution step 181: f(x)= 0.15509045033204855
# differential_evolution step 182: f(x)= 0.15509045033204855
# differential_evolution step 183: f(x)= 0.15509045033204855
# differential_evolution step 184: f(x)= 0.15509045033204855
# differential_evolution step 185: f(x)= 0.15509045033204855
# differential_evolution step 186: f(x)= 0.15509045033204855
# differential_evolution step 187: f(x)= 0.15509045033204855
# differential_evolution step 188: f(x)= 0.15509045033204855
# differential_evolution step 189: f(x)= 0.15509045033204855
# differential_evolution step 190: f(x)= 0.15509045033204855
# differential_evolution step 191: f(x)= 0.15509045033204855
# differential_evolution step 192: f(x)= 0.15509045033204855
# differential_evolution step 193: f(x)= 0.15509045033204855
# differential_evolution step 194: f(x)= 0.15509045033204855
# differential_evolution step 195: f(x)= 0.15509045033204855
# differential_evolution step 196: f(x)= 0.15509045033204855
# differential_evolution step 197: f(x)= 0.15509045033204855
# differential_evolution step 198: f(x)= 0.15509045033204855
# differential_evolution step 199: f(x)= 0.15509045033204855
# differential_evolution step 200: f(x)= 0.15509045033204855
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=727187, Fri Mar 27 20:37:01 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=771374, Fri Mar 27 20:38:09 2026)
# NOTE (module=cma, iteration=703):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.0e+08 to 6.7e+01
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=787376, Fri Mar 27 20:40:10 2026)
# [np.float64(0.1744641798918211), np.float64(0.17421954818671237), np.float64(0.16820502312004582), np.float64(0.1682528303699862), np.float64(0.16811910478231817), np.float64(0.16786868459336088), np.float64(0.16858606109868607), np.float64(0.16866949162096925), np.float64(0.16831920554987057), np.float64(0.16876556545677251), np.float64(0.16787602315308975), np.float64(0.16818181661302392), np.float64(0.16851233752831143), np.float64(0.16829679704557257), np.float64(0.16838634809064468), np.float64(0.1678011181807248), np.float64(0.1689412539008923), np.float64(0.16818927254611224), np.float64(0.16788399812796623), np.float64(0.16830872124591384), np.float64(0.16728004776041705), np.float64(0.16654203847190158), np.float64(0.16674601531869407), np.float64(0.16642978059822333), np.float64(0.16678987070123003), np.float64(0.16651696463252028), np.float64(0.16647809866605984), np.float64(0.1668394846644004), np.float64(0.16664256821624213), np.float64(0.1664712154096143), np.float64(0.16514739626878153), np.float64(0.16500877452599425), np.float64(0.159104309845582), np.float64(0.15854312147901484), np.float64(0.1588433248438193), np.float64(0.15906293443181693), np.float64(0.15893655903353623), np.float64(0.15867678058003995), np.float64(0.1588142049731161), np.float64(0.15889783802489268), np.float64(0.15912959778213429), np.float64(0.15811301153907803), np.float64(0.15883527921991514), np.float64(0.15880267509909418), np.float64(0.15873791764082798), np.float64(0.15875310176963978), np.float64(0.15903452219347058), np.float64(0.1585036479238315), np.float64(0.1588179795859535), np.float64(0.15926413047373236), np.float64(0.15889974710173027), np.float64(0.15857956910786242), np.float64(0.15873917744314922), np.float64(0.1587003506420078), np.float64(0.15927208463629952), np.float64(0.15858578975765672), np.float64(0.15948923824658812), np.float64(0.1587281006548992), np.float64(0.15919875915313514), np.float64(0.15853081317211512), np.float64(0.15817184860896374), np.float64(0.15899907246112063), np.float64(0.15914646465300208), np.float64(0.1588236959458268), np.float64(0.15887193403557542), np.float64(0.15863770787616832), np.float64(0.1587529172759834), np.float64(0.15927736173454907), np.float64(0.1571833193085172), np.float64(0.15681072645874153), np.float64(0.15666580412480705), np.float64(0.15720674800841955), np.float64(0.15813729130283877), np.float64(0.1569401337586833), np.float64(0.157714958591124), np.float64(0.15754343042895053), np.float64(0.15774715019287458), np.float64(0.15793118998355657), np.float64(0.1572015589523417), np.float64(0.15674752199281264), np.float64(0.15634537318566513), np.float64(0.15762382424301338), np.float64(0.15775265282107506), np.float64(0.15748123853059118), np.float64(0.15743732141183056), np.float64(0.15809483946535713), np.float64(0.1564455868639415), np.float64(0.15721347506024466), np.float64(0.15693761917098167), np.float64(0.15750750857197288), np.float64(0.1574855515581559), np.float64(0.15699999186511984), np.float64(0.15595946781134734), np.float64(0.15740016501455714), np.float64(0.15709830971004282), np.float64(0.15743012217692037), np.float64(0.1573537631910567), np.float64(0.1577499653418075), np.float64(0.15821676985709682), np.float64(0.157635565582124), np.float64(0.1572410710352761), np.float64(0.15714073528708566), np.float64(0.15814769849179364), np.float64(0.15653492940834737), np.float64(0.15697677910820065), np.float64(0.1578564713876862), np.float64(0.15670657047611858), np.float64(0.1575940520678801), np.float64(0.15798828679928267), np.float64(0.1578339058124798), np.float64(0.1563429003867744), np.float64(0.1578698258271649), np.float64(0.15709850808381798), np.float64(0.15725591731004893), np.float64(0.15765490717972885), np.float64(0.15767528016524893), np.float64(0.15738357184454652), np.float64(0.15748424992925153), np.float64(0.15731051725346074), np.float64(0.15733816836943568), np.float64(0.15738045848165202), np.float64(0.157390412254196), np.float ...

# %%
predicted_joined_audio = []

for preset, duration in estimated_presets:
    preset = np.expand_dims(preset, axis=0)
    # error = evaluate_presets((denormalize_preset(from_matrix_to_preset(preset)), target_C, duration))
    # print('Error', error)
    # target_audio = np.expand_dims(audio_segments[0], axis=0)
    predicted_audio = render_presets(denormalize_preset(from_matrix_to_preset(preset)), duration)
    predicted_joined_audio.append(predicted_audio[0])

    denormalized_predicted_preset = denormalize_preset(from_matrix_to_preset(preset))
    pretty_print(denormalized_predicted_preset)

predicted_joined_audio = np.concatenate(predicted_joined_audio, axis=0)

print(min(episodes_cma))
# Out:
# {
#   osc1_shape:   [
#     3.99999821058031
#   ]
#   osc1_phase:   [
#     0.025320167259094452
#   ]
#   osc1_volume:   [
#     1.4176524550680376e-07
#   ]
#   osc1_freq:   [
#     19340.53395090875
#   ]
#   osc2_shape:   [
#     0.008022174274781845
#   ]
#   osc2_phase:   [
#     0.7489602715689818
#   ]
#   osc2_volume:   [
#     0.39239094312263934
#   ]
#   osc2_freq:   [
#     22049.997603216972
#   ]
#   osc3_shape:   [
#     0.1323014033336467
#   ]
#   osc3_phase:   [
#     0.1485908787306606
#   ]
#   osc3_volume:   [
#     0.25566908356144585
#   ]
#   osc3_freq:   [
#     22032.034562897657
#   ]
#   osc4_shape:   [
#     0.8594782120445557
#   ]
#   osc4_phase:   [
#     0.7611511370161037
#   ]
#   osc4_volume:   [
#     0.9998435418122672
#   ]
#   osc4_freq:   [
#     440.31040265815255
#   ]
#   oscnoise_volume:   [
#     0.00012776610052095126
#   ]
#   filter_envelope_attack:   [
#     0.1491860819147411
#   ]
#   filter_envelope_decay:   [
#     0.7885616737377851
#   ]
#   filter_envelope_sustain:   [
#     0.4480794526187537
#   ]
#   filter_envelope_release:   [
#     0.007180356705605318
#   ]
#   base_cutoff_hz:   [
#     6448.143907913141
#   ]
#   filter_type:   [
#     1.5119212674293094
#   ]
#   base_q:   [
#     1.0450925489424419
#   ]
#   envelope_depth:   [
#     0.7667894915856096
#   ]
#   envelope_attack:   [
#     1.5784528541661335e-05
#   ]
#   envelope_decay:   [
#     0.00040045394399743767
#   ]
#   envelope_sustain:   [
#     0.38640946576098156
#   ]
#   envelope_release:   [
#     1.8397382193892203e-05
#   ]
# }
# 0.004855690794558076

# %%
spect = evaluate_target(np.array([audio[:120000]]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(audio[:120000], rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spect = evaluate_target(np.array([predicted_joined_audio]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(predicted_joined_audio, rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
