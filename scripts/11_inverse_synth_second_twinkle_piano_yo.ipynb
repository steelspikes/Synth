# %%
import os

# Subir un nivel respecto a la carpeta actual
os.chdir("..")

import numpy as np
from globals import SAMPLE_RATE, PROCESSORS
import librosa
import matplotlib.pyplot as plt
from IPython.display import Audio, display
from scipy.signal import find_peaks

from Utils import load_parameters_file, from_matrix_to_preset, MSE, denormalize_preset, normalize_preset, pretty_print, PARAM_NAMES, from_preset_to_matrix, mel_spectrogram, mfcc, spectrogram
from Synth import Synth
import numpy as np
import cma
import matplotlib.pyplot as plt
from multiprocessing import Pool
from parallelEvaluation import evaluate_presets
from scipy.optimize import differential_evolution

# %%
def get_audio(audio_path):
    y, _sr = librosa.load(audio_path, sr=SAMPLE_RATE)
    y = np.array(y, dtype=np.float64)
    y, _ = librosa.effects.trim(y, top_db=30)

    rms_target = 0.1
    rms_actual = np.sqrt(np.mean(y**2))
    scale = rms_target / (rms_actual + 1e-8)
    return y * scale

def split_audio(audio, prominence=0.01):
    win_size = int(0.02 * SAMPLE_RATE)

    rectified_signal = np.abs(audio)
    window = np.ones(win_size) / win_size
    envelope = np.convolve(rectified_signal, window, mode='same')

    minimals, _ = find_peaks(-envelope, prominence=prominence)
    minimals = np.concatenate((np.array([0]), minimals))

    minimals = minimals + (win_size // 2)

    audios = []
    
    for i in range(minimals.shape[0]):
        if i < minimals.shape[0] - 1:
            audios.append(audio[minimals[i] : minimals[i+1]])
        else:
            audios.append(audio[minimals[i]:])

    return audios

# %%
def render_presets(presets, duration=0):
    synth = Synth(
        sample_rate=SAMPLE_RATE,
        duration=duration,
        presets=presets
    )
    return synth.process_audio().astype(np.float64)

def evaluate_target(audio):
    return mel_spectrogram(audio, sr=SAMPLE_RATE, n_fft=2048, hop_length=256, n_mels=128)

# %%
def search_with_DE(target_C, duration):
    bounds = [(0, 1)] * len(PARAM_NAMES)

    with Pool(PROCESSORS) as pool:
        def get_fitness(solutions):
            solutions = np.array(solutions).T
            solutions_splitted = np.array_split(solutions, PROCESSORS)
            presets_splitted = [(denormalize_preset(from_matrix_to_preset(chunk)), target_C, duration) for chunk in solutions_splitted]
            
            solutions_evaluated = pool.map(evaluate_presets, presets_splitted)
            return np.concatenate(solutions_evaluated).tolist()
            
        result = differential_evolution(
            get_fitness,
            bounds=bounds,
            popsize=10,        # 10 × n_params individuos
            mutation=(0.5, 1),
            recombination=0.7,
            tol=1e-4,
            maxiter=150,
            polish=False,
            seed=None,
            disp=False,
            workers=1,
            vectorized=True,
            strategy='rand1bin'
        )

        x_best = result.x
        f_best = result.fun

        return x_best

# %%
def search_with_CMA(target_C, duration, x0):
    sigma0 = 0.04

    with Pool(PROCESSORS) as pool:
        def get_fitness(solutions):
            solutions = np.array(solutions)
            solutions_splitted = np.array_split(solutions, PROCESSORS)
            presets_splitted = [(denormalize_preset(from_matrix_to_preset(chunk)), target_C, duration) for chunk in solutions_splitted]
            
            solutions_evaluated = pool.map(evaluate_presets, presets_splitted)
            return np.concatenate(solutions_evaluated)
        
        bestever = cma.optimization_tools.BestSolution()

        for i in range(3):
            options = {
                'popsize': 30,
                'bounds': [np.zeros_like(x0), np.ones_like(x0)],
                'tolfun': 5e-4,
                'tolx': 5e-4,
                'tolfunhist': 5e-4
            }

            es = cma.CMAEvolutionStrategy(x0, sigma0, options)
            gen = 1

            while not es.stop():
                solutions = np.array(es.ask())  # devuelve una lista de individuos

                fitnesses = get_fitness(solutions)

                best_idx = np.argmin(fitnesses)          # índice del mejor fitness
                best_fitness = fitnesses[best_idx]       # fitness correspondiente

                # if gen % 100 == 0:
                #     print("Gen", gen, "Mejor fitness:", best_fitness, "Sigma", es.sigma, "Restart", i + 1)

                es.tell(solutions, fitnesses)  # pasar fitness al algoritmo

                gen += 1

            bestever.update(es.best)
        
        return bestever.get()[0]

# %%
audio_path = 'C:/Users/bryan/Documents/GitHub/Synth/presets/TwinkleFast.m4a'
audio = get_audio(audio_path) # Quitar esto

plt.plot(audio)
plt.show()
Audio(audio, rate=SAMPLE_RATE)
# Out:
# C:\Users\bryan\AppData\Local\Temp\ipykernel_12280\2556869454.py:2: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _sr = librosa.load(audio_path, sr=SAMPLE_RATE)
# c:\Users\bryan\Documents\GitHub\Synth\venv\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_segments = split_audio(audio, prominence=0.025)

for audio_segment in audio_segments:
    plt.plot(audio_segment)
    plt.show()
    display(Audio(audio_segment, rate=SAMPLE_RATE))

print('Pieces', len(audio_segments))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Pieces 15

# %%
estimated_presets = []
i = 1

if __name__ == '__main__':
    for audio_segment in audio_segments:
        print('Piece', i)
        target_C = evaluate_target(np.expand_dims(audio_segment, axis=0))
        duration = len(audio_segment) / SAMPLE_RATE
        best = search_with_DE(target_C, duration)
        best = search_with_CMA(target_C, duration, best)
        estimated_presets.append((best, duration))
        i+=1
# Out:
# Piece 1
# c:\Users\bryan\Documents\GitHub\Synth\venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:487: UserWarning: differential_evolution: the 'vectorized' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=314256, Wed Feb  4 14:56:44 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=426693, Wed Feb  4 14:58:11 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=303576, Wed Feb  4 15:00:27 2026)
# Piece 2
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=408354, Wed Feb  4 15:03:52 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=403722, Wed Feb  4 15:05:36 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=320002, Wed Feb  4 15:06:36 2026)
# Piece 3
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=387712, Wed Feb  4 15:09:42 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=390468, Wed Feb  4 15:10:10 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=344905, Wed Feb  4 15:11:19 2026)
# Piece 4
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=326052, Wed Feb  4 15:14:18 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=348019, Wed Feb  4 15:15:25 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=332279, Wed Feb  4 15:16:09 2026)
# Piece 5
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=288925, Wed Feb  4 15:21:20 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=352171, Wed Feb  4 15:22:33 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=282636, Wed Feb  4 15:24:04 2026)
# Piece 6
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=310368, Wed Feb  4 15:27:15 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=352812, Wed Feb  4 15:28:17 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=402467, Wed Feb  4 15:29:20 2026)
# Piece 7
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=338472, Wed Feb  4 15:34:40 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=330911, Wed Feb  4 15:37:56 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=358051, Wed Feb  4 15:39:41 2026)
# Piece 8
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=339792, Wed Feb  4 15:44:19 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=381419, Wed Feb  4 15:46:42 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=281061, Wed Feb  4 15:47:48 2026)
# Piece 9
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=270797, Wed Feb  4 15:51:52 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=387669, Wed Feb  4 15:53:04 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=383727, Wed Feb  4 15:54:41 2026)
# Piece 10
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=316058, Wed Feb  4 15:58:52 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=395351, Wed Feb  4 16:02:52 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=375996, Wed Feb  4 16:04:38 2026)
# Piece 11
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=301618, Wed Feb  4 16:09:57 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=419908, Wed Feb  4 16:10:52 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=370108, Wed Feb  4 16:11:30 2026)
# Piece 12
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=415035, Wed Feb  4 16:14:55 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=302153, Wed Feb  4 16:16:38 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=395926, Wed Feb  4 16:19:24 2026)
# Piece 13
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=307451, Wed Feb  4 16:25:05 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=275041, Wed Feb  4 16:26:49 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=277902, Wed Feb  4 16:29:43 2026)
# Piece 14
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=351267, Wed Feb  4 16:31:58 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=271660, Wed Feb  4 16:33:45 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=366658, Wed Feb  4 16:34:24 2026)
# Piece 15
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=344178, Wed Feb  4 16:37:43 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=380925, Wed Feb  4 16:39:09 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=287004, Wed Feb  4 16:40:33 2026)

# %%
predicted_joined_audio = []

for preset, duration in estimated_presets:
    preset = np.expand_dims(preset, axis=0)
    # error = evaluate_presets((denormalize_preset(from_matrix_to_preset(preset)), target_C, duration))
    # print('Error', error)
    # target_audio = np.expand_dims(audio_segments[0], axis=0)
    predicted_audio = render_presets(denormalize_preset(from_matrix_to_preset(preset)), duration)
    predicted_joined_audio.append(predicted_audio[0])

    denormalized_predicted_preset = denormalize_preset(from_matrix_to_preset(preset))
    pretty_print(denormalized_predicted_preset)

predicted_joined_audio = np.concatenate(predicted_joined_audio, axis=0)
# Out:
# {
#   osc1_shape:   [
#     1.86089059268547
#   ]
#   osc1_phase:   [
#     0.532379333119865
#   ]
#   osc1_volume:   [
#     0.40427440771527706
#   ]
#   osc1_freq:   [
#     261.4645561778902
#   ]
#   osc2_shape:   [
#     0.1658015128864218
#   ]
#   osc2_phase:   [
#     0.3788615392462597
#   ]
#   osc2_volume:   [
#     0.662667387406945
#   ]
#   osc2_freq:   [
#     1844.4771937068203
#   ]
#   osc3_shape:   [
#     2.1846254779626273
#   ]
#   osc3_phase:   [
#     0.013792343478970735
#   ]
#   osc3_volume:   [
#     0.0788760943233439
#   ]
#   osc3_freq:   [
#     1341.7275597335063
#   ]
#   osc4_shape:   [
#     1.6217141519677118
#   ]
#   osc4_phase:   [
#     0.8158601148403889
#   ]
#   osc4_volume:   [
#     0.01691794969687543
#   ]
#   osc4_freq:   [
#     73.800088808072
#   ]
#   oscnoise_volume:   [
#     0.0902424288760616
#   ]
#   filter_envelope_attack:   [
#     0.4978865499708307
#   ]
#   filter_envelope_decay:   [
#     0.38455473058279716
#   ]
#   filter_envelope_sustain:   [
#     0.709536076953022
#   ]
#   filter_envelope_release:   [
#     0.3474899180706541
#   ]
#   base_cutoff_hz:   [
#     341.51914121403973
#   ]
#   filter_type:   [
#     1.6037129853913483
#   ]
#   base_q:   [
#     7.004086453039882
#   ]
#   envelope_depth:   [
#     0.17594125471451824
#   ]
#   envelope_attack:   [
#     0.0010014147807821381
#   ]
#   envelope_decay:   [
#     0.1654285000466528
#   ]
#   envelope_sustain:   [
#     0.8690510777773763
#   ]
#   envelope_release:   [
#     0.4598664133551743
#   ]
# }
# {
#   osc1_shape:   [
#     0.05417585960125603
#   ]
#   osc1_phase:   [
#     0.14926054435083627
#   ]
#   osc1_volume:   [
#     0.12093264269393472
#   ]
#   osc1_freq:   [
#     526.920445167507
#   ]
#   osc2_shape:   [
#     1.0799095433667154
#   ]
#   osc2_phase:   [
#     0.0024176215589998755
#   ]
#   osc2_volume:   [
#     0.7553469048480986
#   ]
#   osc2_freq:   [
#     1843.8160509756933
#   ]
#   osc3_shape:   [
#     0.4537813745422361
#   ]
#   osc3_phase:   [
#     0.5581910320571081
#   ]
#   osc3_volume:   [
#     0.6113598707912723
#   ]
#   osc3_freq:   [
#     1310.860951795712
#   ]
#   osc4_shape:   [
#     1.9904910557858544
#   ]
#   osc4_phase:   [
#     0.8730429711636348
#   ]
#   osc4_volume:   [
#     0.792546532788931
#   ]
#   osc4_freq:   [
#     262.04869817403574
#   ]
#   oscnoise_volume:   [
#     0.016311380375003657
#   ]
#   filter_envelope_attack:   [
#     0.40762440650849124
#   ]
#   filter_envelope_decay:   [
#     0.4745019540657018
#   ]
#   filter_envelope_sustain:   [
#     0.23904732662537012
#   ]
#   filter_envelope_release:   [
#     0.15486185202131442
#   ]
#   base_cutoff_hz:   [
#     217.81748214061622
#   ]
#   filter_type:   [
#     1.9895033844093029
#   ]
#   base_q:   [
#     1.0773031760404017
#   ]
#   envelope_depth:   [
#     0.006233894958204078
#   ]
#   envelope_attack:   [
#     0.006364119801444416
#   ]
#   envelope_decay:   [
#     0.15771393343406617
#   ]
#   envelope_sustain:   [
#     0.9100537441067391
#   ]
#   envelope_release:   [
#     0.24330500943242064
#   ]
# }
# {
#   osc1_shape:   [
#     1.7613309811816427
#   ]
#   osc1_phase:   [
#     0.6808728258331648
#   ]
#   osc1_volume:   [
#     0.7512750238207796
#   ]
#   osc1_freq:   [
#     68.69153714278316
#   ]
#   osc2_shape:   [
#     1.9559064897563123
#   ]
#   osc2_phase:   [
#     0.9945041694228272
#   ]
#   osc2_volume:   [
#     0.43125469956270407
#   ]
#   osc2_freq:   [
#     398.3212160186523
#   ]
#   osc3_shape:   [
#     1.4865475369172623
#   ]
#   osc3_phase:   [
#     0.9348636105278063
#   ]
#   osc3_volume:   [
#     0.4491556278051587
#   ]
#   osc3_freq:   [
#     378.756102687744
#   ]
#   osc4_shape:   [
#     0.9927534256208683
#   ]
#   osc4_phase:   [
#     0.213846672342739
#   ]
#   osc4_volume:   [
#     0.5733583326936743
#   ]
#   osc4_freq:   [
#     1194.4177149099091
#   ]
#   oscnoise_volume:   [
#     0.25998906330678634
#   ]
#   filter_envelope_attack:   [
#     0.26163068335298345
#   ]
#   filter_envelope_decay:   [
#     0.16447205595802517
#   ]
#   filter_envelope_sustain:   [
#     0.6838647903622265
#   ]
#   filter_envelope_release:   [
#     0.3395595519796861
#   ]
#   base_cutoff_hz:   [
#     286.42208798165024
#   ]
#   filter_type:   [
#     1.0097196057124935
#   ]
#   base_q:   [
#     4.776434773863096
#   ]
#   envelope_depth:   [
#     0.3951517059139728
#   ]
#   envelope_attack:   [
#     2.0127597899762082e-05
#   ]
#   envelope_decay:   [
#     0.029089458541414287
#   ]
#   envelope_sustain:   [
#     0.3601909701844778
#   ]
#   envelope_release:   [
#     0.45657234813163977
#   ]
# }
# {
#   osc1_shape:   [
#     1.2762149356921355
#   ]
#   osc1_phase:   [
#     0.49722038727191886
#   ]
#   osc1_volume:   [
#     0.6767840144416409
#   ]
#   osc1_freq:   [
#     1187.852956765118
#   ]
#   osc2_shape:   [
#     3.675272138770684
#   ]
#   osc2_phase:   [
#     0.6263980154117073
#   ]
#   osc2_volume:   [
#     0.004666991964429456
#   ]
#   osc2_freq:   [
#     245.7626469640304
#   ]
#   osc3_shape:   [
#     1.2273981905513798
#   ]
#   osc3_phase:   [
#     0.4865317984601958
#   ]
#   osc3_volume:   [
#     0.05232928107959451
#   ]
#   osc3_freq:   [
#     177.37786836105886
#   ]
#   osc4_shape:   [
#     1.5659093706536469
#   ]
#   osc4_phase:   [
#     0.5810719860979663
#   ]
#   osc4_volume:   [
#     0.23317201119610287
#   ]
#   osc4_freq:   [
#     266.16122461939125
#   ]
#   oscnoise_volume:   [
#     0.8489138323187203
#   ]
#   filter_envelope_attack:   [
#     0.48742597527414144
#   ]
#   filter_envelope_decay:   [
#     0.0712947139869333
#   ]
#   filter_envelope_sustain:   [
#     0.4826352544653332
#   ]
#   filter_envelope_release:   [
#     0.16919376182356632
#   ]
#   base_cutoff_hz:   [
#     385.5510186280481
#   ]
#   filter_type:   [
#     1.666084227185224
#   ]
#   base_q:   [
#     14.643542875507947
#   ]
#   envelope_depth:   [
#     0.010998690190192947
#   ]
#   envelope_attack:   [
#     0.00033451134714588274
#   ]
#   envelope_decay:   [
#     0.0008455383653148927
#   ]
#   envelope_sustain:   [
#     0.29931589091926525
#   ]
#   envelope_release:   [
#     0.2635376062468496
#   ]
# }
# {
#   osc1_shape:   [
#     3.142366554159135
#   ]
#   osc1_phase:   [
#     0.37749436493625316
#   ]
#   osc1_volume:   [
#     0.663059863431225
#   ]
#   osc1_freq:   [
#     20.093296217940157
#   ]
#   osc2_shape:   [
#     0.15048312586970375
#   ]
#   osc2_phase:   [
#     0.8045414010826722
#   ]
#   osc2_volume:   [
#     0.08833175535056596
#   ]
#   osc2_freq:   [
#     74.69203594034036
#   ]
#   osc3_shape:   [
#     3.373909121893139
#   ]
#   osc3_phase:   [
#     0.61507648957686
#   ]
#   osc3_volume:   [
#     0.8371187025614023
#   ]
#   osc3_freq:   [
#     448.6484158623091
#   ]
#   osc4_shape:   [
#     0.0002096074471093362
#   ]
#   osc4_phase:   [
#     0.1923531162486288
#   ]
#   osc4_volume:   [
#     0.9764054260272892
#   ]
#   osc4_freq:   [
#     1325.6802233832295
#   ]
#   oscnoise_volume:   [
#     0.669350067535666
#   ]
#   filter_envelope_attack:   [
#     0.36684571199883587
#   ]
#   filter_envelope_decay:   [
#     0.3891370455172492
#   ]
#   filter_envelope_sustain:   [
#     0.5479860844708488
#   ]
#   filter_envelope_release:   [
#     0.3642712796138801
#   ]
#   base_cutoff_hz:   [
#     356.8046773324518
#   ]
#   filter_type:   [
#     1.0019857645359884
#   ]
#   base_q:   [
#     4.122744582599084
#   ]
#   envelope_depth:   [
#     0.006224003633405643
#   ]
#   envelope_attack:   [
#     0.015803357149711452
#   ]
#   envelope_decay:   [
#     0.0008886488240257369
#   ]
#   envelope_sustain:   [
#     0.2976415805112753
#   ]
#   envelope_release:   [
#     0.3203640259273244
#   ]
# }
# {
#   osc1_shape:   [
#     0.9220749043283168
#   ]
#   osc1_phase:   [
#     0.5017339744700814
#   ]
#   osc1_volume:   [
#     0.6104411551981435
#   ]
#   osc1_freq:   [
#     1330.8745478857882
#   ]
#   osc2_shape:   [
#     3.979473801976889
#   ]
#   osc2_phase:   [
#     0.5960771730182274
#   ]
#   osc2_volume:   [
#     0.8747230372336146
#   ]
#   osc2_freq:   [
#     64.42914262899936
#   ]
#   osc3_shape:   [
#     1.9910386113140648
#   ]
#   osc3_phase:   [
#     0.07467368609891176
#   ]
#   osc3_volume:   [
#     0.6712473439164818
#   ]
#   osc3_freq:   [
#     443.7181395915929
#   ]
#   osc4_shape:   [
#     1.4179664845213873
#   ]
#   osc4_phase:   [
#     0.3582579147057062
#   ]
#   osc4_volume:   [
#     0.5557839277307359
#   ]
#   osc4_freq:   [
#     15219.76843497923
#   ]
#   oscnoise_volume:   [
#     0.4567069723398123
#   ]
#   filter_envelope_attack:   [
#     0.3181589484454063
#   ]
#   filter_envelope_decay:   [
#     0.8037823368327262
#   ]
#   filter_envelope_sustain:   [
#     0.8647375968921266
#   ]
#   filter_envelope_release:   [
#     0.34040232340923776
#   ]
#   base_cutoff_hz:   [
#     355.1442242414114
#   ]
#   filter_type:   [
#     1.2474877632980648
#   ]
#   base_q:   [
#     10.692620447115107
#   ]
#   envelope_depth:   [
#     0.8379297364956848
#   ]
#   envelope_attack:   [
#     0.012082746645833472
#   ]
#   envelope_decay:   [
#     0.0008385381128793584
#   ]
#   envelope_sustain:   [
#     0.43625365103308705
#   ]
#   envelope_release:   [
#     0.4836331236054588
#   ]
# }
# {
#   osc1_shape:   [
#     1.0062109506701424
#   ]
#   osc1_phase:   [
#     0.1965014195790895
#   ]
#   osc1_volume:   [
#     0.33753753664946634
#   ]
#   osc1_freq:   [
#     1581.1845346097082
#   ]
#   osc2_shape:   [
#     2.2879969100301376
#   ]
#   osc2_phase:   [
#     0.6717596288517194
#   ]
#   osc2_volume:   [
#     0.08918551348880514
#   ]
#   osc2_freq:   [
#     438.6585513485906
#   ]
#   osc3_shape:   [
#     1.9105261273025438
#   ]
#   osc3_phase:   [
#     0.7438764355493143
#   ]
#   osc3_volume:   [
#     0.05459330524462343
#   ]
#   osc3_freq:   [
#     1815.2054699725663
#   ]
#   osc4_shape:   [
#     2.0775977804069465
#   ]
#   osc4_phase:   [
#     0.9061945749727659
#   ]
#   osc4_volume:   [
#     0.4163264112370631
#   ]
#   osc4_freq:   [
#     394.78250227209963
#   ]
#   oscnoise_volume:   [
#     0.38738168752768287
#   ]
#   filter_envelope_attack:   [
#     0.005769170450933986
#   ]
#   filter_envelope_decay:   [
#     0.008857911461330036
#   ]
#   filter_envelope_sustain:   [
#     0.6718697620156161
#   ]
#   filter_envelope_release:   [
#     0.3042880660306961
#   ]
#   base_cutoff_hz:   [
#     174.340446552403
#   ]
#   filter_type:   [
#     1.3544686417397085
#   ]
#   base_q:   [
#     3.130291680644102
#   ]
#   envelope_depth:   [
#     0.10810145252769628
#   ]
#   envelope_attack:   [
#     0.02757749594202302
#   ]
#   envelope_decay:   [
#     0.27497128699522844
#   ]
#   envelope_sustain:   [
#     0.16344519487755593
#   ]
#   envelope_release:   [
#     0.0001774788598474917
#   ]
# }
# {
#   osc1_shape:   [
#     2.824749728576606
#   ]
#   osc1_phase:   [
#     0.5679325444657922
#   ]
#   osc1_volume:   [
#     0.14530582856427393
#   ]
#   osc1_freq:   [
#     1755.1470879085978
#   ]
#   osc2_shape:   [
#     1.8591817016148164
#   ]
#   osc2_phase:   [
#     0.6232635729504887
#   ]
#   osc2_volume:   [
#     3.859843712302234e-05
#   ]
#   osc2_freq:   [
#     117.58309073105269
#   ]
#   osc3_shape:   [
#     1.4303487215679578
#   ]
#   osc3_phase:   [
#     0.4053946039878892
#   ]
#   osc3_volume:   [
#     0.46512933839770204
#   ]
#   osc3_freq:   [
#     1412.474533788439
#   ]
#   osc4_shape:   [
#     1.895111699597603
#   ]
#   osc4_phase:   [
#     0.6971245870736076
#   ]
#   osc4_volume:   [
#     0.3158577511012311
#   ]
#   osc4_freq:   [
#     1066.9557574222183
#   ]
#   oscnoise_volume:   [
#     0.9991838428835459
#   ]
#   filter_envelope_attack:   [
#     0.001550488182191645
#   ]
#   filter_envelope_decay:   [
#     0.989265498246391
#   ]
#   filter_envelope_sustain:   [
#     0.7795501678059755
#   ]
#   filter_envelope_release:   [
#     0.09491423260814973
#   ]
#   base_cutoff_hz:   [
#     335.04061422975866
#   ]
#   filter_type:   [
#     1.868820767455837
#   ]
#   base_q:   [
#     17.17946731304213
#   ]
#   envelope_depth:   [
#     0.002072922097971704
#   ]
#   envelope_attack:   [
#     0.013138112771168345
#   ]
#   envelope_decay:   [
#     0.0009053279116490124
#   ]
#   envelope_sustain:   [
#     0.400148919281721
#   ]
#   envelope_release:   [
#     0.24150255435196555
#   ]
# }
# {
#   osc1_shape:   [
#     1.4395027285144717
#   ]
#   osc1_phase:   [
#     0.936301145606569
#   ]
#   osc1_volume:   [
#     0.6103156351249127
#   ]
#   osc1_freq:   [
#     20813.269037091115
#   ]
#   osc2_shape:   [
#     2.1585017362306074
#   ]
#   osc2_phase:   [
#     0.7307076593043488
#   ]
#   osc2_volume:   [
#     0.03130164121866815
#   ]
#   osc2_freq:   [
#     19544.6746645377
#   ]
#   osc3_shape:   [
#     1.7449714734637112
#   ]
#   osc3_phase:   [
#     0.0998110697745245
#   ]
#   osc3_volume:   [
#     0.003207622147566949
#   ]
#   osc3_freq:   [
#     2345.578370932011
#   ]
#   osc4_shape:   [
#     1.9825249925570596
#   ]
#   osc4_phase:   [
#     0.34996219356543234
#   ]
#   osc4_volume:   [
#     0.5997477549161299
#   ]
#   osc4_freq:   [
#     353.1188996150581
#   ]
#   oscnoise_volume:   [
#     0.7580128399939567
#   ]
#   filter_envelope_attack:   [
#     0.490683867855617
#   ]
#   filter_envelope_decay:   [
#     0.23956805000935588
#   ]
#   filter_envelope_sustain:   [
#     0.799797959499038
#   ]
#   filter_envelope_release:   [
#     0.39211397325467456
#   ]
#   base_cutoff_hz:   [
#     369.916731219541
#   ]
#   filter_type:   [
#     1.9801114703500393
#   ]
#   base_q:   [
#     0.7075777569711572
#   ]
#   envelope_depth:   [
#     0.9455252744728074
#   ]
#   envelope_attack:   [
#     0.0029216136622011077
#   ]
#   envelope_decay:   [
#     0.00032918308892972175
#   ]
#   envelope_sustain:   [
#     0.6796376219543506
#   ]
#   envelope_release:   [
#     0.49840785427823175
#   ]
# }
# {
#   osc1_shape:   [
#     1.0433341420938913
#   ]
#   osc1_phase:   [
#     0.9482544431599335
#   ]
#   osc1_volume:   [
#     0.07159857500150305
#   ]
#   osc1_freq:   [
#     7760.0167432167755
#   ]
#   osc2_shape:   [
#     1.0021501793257768
#   ]
#   osc2_phase:   [
#     0.8357653971713674
#   ]
#   osc2_volume:   [
#     0.09160724381604804
#   ]
#   osc2_freq:   [
#     2117.609819546291
#   ]
#   osc3_shape:   [
#     2.771457784133601
#   ]
#   osc3_phase:   [
#     0.21534022373887313
#   ]
#   osc3_volume:   [
#     0.07779524860739195
#   ]
#   osc3_freq:   [
#     10660.70009808351
#   ]
#   osc4_shape:   [
#     1.9039729371377685
#   ]
#   osc4_phase:   [
#     0.1673220194498286
#   ]
#   osc4_volume:   [
#     0.30404352640593385
#   ]
#   osc4_freq:   [
#     662.7460571908122
#   ]
#   oscnoise_volume:   [
#     0.6041864272619577
#   ]
#   filter_envelope_attack:   [
#     0.46280277378572177
#   ]
#   filter_envelope_decay:   [
#     0.05849862168669628
#   ]
#   filter_envelope_sustain:   [
#     0.9099746293427778
#   ]
#   filter_envelope_release:   [
#     0.1565992185295199
#   ]
#   base_cutoff_hz:   [
#     308.3509841763073
#   ]
#   filter_type:   [
#     1.906309335494929
#   ]
#   base_q:   [
#     18.99703218327513
#   ]
#   envelope_depth:   [
#     0.08210916913581238
#   ]
#   envelope_attack:   [
#     0.0071787955221640125
#   ]
#   envelope_decay:   [
#     0.17880712594405512
#   ]
#   envelope_sustain:   [
#     0.14264270913830035
#   ]
#   envelope_release:   [
#     0.00031089999924465903
#   ]
# }
# {
#   osc1_shape:   [
#     0.011710719190735632
#   ]
#   osc1_phase:   [
#     0.5882108947841792
#   ]
#   osc1_volume:   [
#     0.6821629770794575
#   ]
#   osc1_freq:   [
#     1994.9984156760938
#   ]
#   osc2_shape:   [
#     1.4558318430440622
#   ]
#   osc2_phase:   [
#     0.8969327531812635
#   ]
#   osc2_volume:   [
#     0.990493085578595
#   ]
#   osc2_freq:   [
#     332.1503930045514
#   ]
#   osc3_shape:   [
#     3.9688103885492754
#   ]
#   osc3_phase:   [
#     0.9002258209121697
#   ]
#   osc3_volume:   [
#     0.14391975615179797
#   ]
#   osc3_freq:   [
#     97.03270625816727
#   ]
#   osc4_shape:   [
#     2.1576517613196207
#   ]
#   osc4_phase:   [
#     0.7412198403568104
#   ]
#   osc4_volume:   [
#     0.2567317316494253
#   ]
#   osc4_freq:   [
#     70.38247421866217
#   ]
#   oscnoise_volume:   [
#     0.056784239755592054
#   ]
#   filter_envelope_attack:   [
#     0.299087065295746
#   ]
#   filter_envelope_decay:   [
#     0.5647688027854856
#   ]
#   filter_envelope_sustain:   [
#     0.6209827323857499
#   ]
#   filter_envelope_release:   [
#     0.26189216480685656
#   ]
#   base_cutoff_hz:   [
#     228.9571742976327
#   ]
#   filter_type:   [
#     1.0107946297980215
#   ]
#   base_q:   [
#     2.0357320812406283
#   ]
#   envelope_depth:   [
#     0.597699613101802
#   ]
#   envelope_attack:   [
#     0.01780628762975756
#   ]
#   envelope_decay:   [
#     0.001326183253528944
#   ]
#   envelope_sustain:   [
#     0.4611029819263324
#   ]
#   envelope_release:   [
#     0.4922945632234415
#   ]
# }
# {
#   osc1_shape:   [
#     0.0011934687021694023
#   ]
#   osc1_phase:   [
#     0.4622592442963678
#   ]
#   osc1_volume:   [
#     0.007970970232920998
#   ]
#   osc1_freq:   [
#     225.88217706227152
#   ]
#   osc2_shape:   [
#     1.7306104362541928
#   ]
#   osc2_phase:   [
#     0.5711832515169607
#   ]
#   osc2_volume:   [
#     0.0132187858660293
#   ]
#   osc2_freq:   [
#     184.589889766792
#   ]
#   osc3_shape:   [
#     2.1699860904292962
#   ]
#   osc3_phase:   [
#     0.716800701651714
#   ]
#   osc3_volume:   [
#     0.3526114541116543
#   ]
#   osc3_freq:   [
#     294.8088714793697
#   ]
#   osc4_shape:   [
#     1.1012776065118177
#   ]
#   osc4_phase:   [
#     0.7540973234374746
#   ]
#   osc4_volume:   [
#     0.20926874045723987
#   ]
#   osc4_freq:   [
#     2371.5120241648983
#   ]
#   oscnoise_volume:   [
#     0.17241040283078965
#   ]
#   filter_envelope_attack:   [
#     0.2970810036994097
#   ]
#   filter_envelope_decay:   [
#     0.7697803278528722
#   ]
#   filter_envelope_sustain:   [
#     0.8567846919381544
#   ]
#   filter_envelope_release:   [
#     0.30844966533509144
#   ]
#   base_cutoff_hz:   [
#     581.047377964579
#   ]
#   filter_type:   [
#     1.9814861258260774
#   ]
#   base_q:   [
#     1.0892110203623466
#   ]
#   envelope_depth:   [
#     0.11722738807693879
#   ]
#   envelope_attack:   [
#     0.02671286824905741
#   ]
#   envelope_decay:   [
#     0.2985123568223908
#   ]
#   envelope_sustain:   [
#     0.5643347725000777
#   ]
#   envelope_release:   [
#     0.4624651608245757
#   ]
# }
# {
#   osc1_shape:   [
#     0.9980253194869068
#   ]
#   osc1_phase:   [
#     0.6224919248655539
#   ]
#   osc1_volume:   [
#     0.3127862962423319
#   ]
#   osc1_freq:   [
#     2072.11154161221
#   ]
#   osc2_shape:   [
#     3.4104749698487375
#   ]
#   osc2_phase:   [
#     0.6569602771471141
#   ]
#   osc2_volume:   [
#     0.007120098693580851
#   ]
#   osc2_freq:   [
#     259.8637957981507
#   ]
#   osc3_shape:   [
#     1.5835858815715755
#   ]
#   osc3_phase:   [
#     0.12431348865898405
#   ]
#   osc3_volume:   [
#     0.0010304922473484425
#   ]
#   osc3_freq:   [
#     39.323674089411085
#   ]
#   osc4_shape:   [
#     1.9877752679254947
#   ]
#   osc4_phase:   [
#     0.4317578218110679
#   ]
#   osc4_volume:   [
#     0.9983151261613227
#   ]
#   osc4_freq:   [
#     296.3128314627163
#   ]
#   oscnoise_volume:   [
#     0.6691990134897811
#   ]
#   filter_envelope_attack:   [
#     0.486206824208247
#   ]
#   filter_envelope_decay:   [
#     0.24148325165882034
#   ]
#   filter_envelope_sustain:   [
#     0.4433037475736285
#   ]
#   filter_envelope_release:   [
#     0.48155778752169187
#   ]
#   base_cutoff_hz:   [
#     227.53225218176397
#   ]
#   filter_type:   [
#     1.233678698160492
#   ]
#   base_q:   [
#     6.528938152390966
#   ]
#   envelope_depth:   [
#     0.43514854883616666
#   ]
#   envelope_attack:   [
#     0.007006089782252219
#   ]
#   envelope_decay:   [
#     0.2999439281812172
#   ]
#   envelope_sustain:   [
#     0.3244001026967187
#   ]
#   envelope_release:   [
#     0.22990060151468225
#   ]
# }
# {
#   osc1_shape:   [
#     2.8229887179981357
#   ]
#   osc1_phase:   [
#     0.6400078186376648
#   ]
#   osc1_volume:   [
#     0.3993323446814366
#   ]
#   osc1_freq:   [
#     15424.942763562185
#   ]
#   osc2_shape:   [
#     3.8936805890348696
#   ]
#   osc2_phase:   [
#     0.5344397894172553
#   ]
#   osc2_volume:   [
#     0.5767026432184986
#   ]
#   osc2_freq:   [
#     263.3197992347234
#   ]
#   osc3_shape:   [
#     0.36297824959369035
#   ]
#   osc3_phase:   [
#     0.02672322280620241
#   ]
#   osc3_volume:   [
#     0.38354984458453495
#   ]
#   osc3_freq:   [
#     24.600071307433275
#   ]
#   osc4_shape:   [
#     3.992204877916051
#   ]
#   osc4_phase:   [
#     0.2664633202040479
#   ]
#   osc4_volume:   [
#     0.11253153820974886
#   ]
#   osc4_freq:   [
#     52.2880831346125
#   ]
#   oscnoise_volume:   [
#     0.3790297201464324
#   ]
#   filter_envelope_attack:   [
#     0.13305252952888252
#   ]
#   filter_envelope_decay:   [
#     0.6073445545537702
#   ]
#   filter_envelope_sustain:   [
#     0.5593186811852645
#   ]
#   filter_envelope_release:   [
#     0.40727268506913405
#   ]
#   base_cutoff_hz:   [
#     444.3984967028136
#   ]
#   filter_type:   [
#     1.998857580357296
#   ]
#   base_q:   [
#     1.9894383935577362
#   ]
#   envelope_depth:   [
#     0.852718062759124
#   ]
#   envelope_attack:   [
#     0.004454971741114607
#   ]
#   envelope_decay:   [
#     0.16288144291456397
#   ]
#   envelope_sustain:   [
#     0.2862009115525823
#   ]
#   envelope_release:   [
#     0.40737567978685896
#   ]
# }
# {
#   osc1_shape:   [
#     0.26169489108371685
#   ]
#   osc1_phase:   [
#     0.5643857267104179
#   ]
#   osc1_volume:   [
#     0.9107185881256153
#   ]
#   osc1_freq:   [
#     264.99380948523657
#   ]
#   osc2_shape:   [
#     3.2692595570955687
#   ]
#   osc2_phase:   [
#     0.6893089820038326
#   ]
#   osc2_volume:   [
#     0.9092825545241963
#   ]
#   osc2_freq:   [
#     262.8169298788988
#   ]
#   osc3_shape:   [
#     2.2137645713936065
#   ]
#   osc3_phase:   [
#     0.9008050431474255
#   ]
#   osc3_volume:   [
#     0.20944105218996734
#   ]
#   osc3_freq:   [
#     2103.2857954487117
#   ]
#   osc4_shape:   [
#     1.99874151781896
#   ]
#   osc4_phase:   [
#     0.7070991174124125
#   ]
#   osc4_volume:   [
#     0.1520401947479358
#   ]
#   osc4_freq:   [
#     55.53970306914166
#   ]
#   oscnoise_volume:   [
#     0.7945257054726103
#   ]
#   filter_envelope_attack:   [
#     0.3059709593602456
#   ]
#   filter_envelope_decay:   [
#     0.6567662381060186
#   ]
#   filter_envelope_sustain:   [
#     0.09028881142002586
#   ]
#   filter_envelope_release:   [
#     0.2562943665992724
#   ]
#   base_cutoff_hz:   [
#     275.3061985539192
#   ]
#   filter_type:   [
#     1.219836490332321
#   ]
#   base_q:   [
#     1.6726635172848083
#   ]
#   envelope_depth:   [
#     0.027430978482857218
#   ]
#   envelope_attack:   [
#     0.00015997009166282482
#   ]
#   envelope_decay:   [
#     0.01457999219307661
#   ]
#   envelope_sustain:   [
#     0.30776224836262445
#   ]
#   envelope_release:   [
#     0.32975895387399135
#   ]
# }

# %%
spect = evaluate_target(np.array([audio]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(audio, rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spect = evaluate_target(np.array([predicted_joined_audio]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(predicted_joined_audio, rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
