# %%
import os

# Subir un nivel respecto a la carpeta actual
os.chdir("..")

import numpy as np
from globals import SAMPLE_RATE
import librosa
import matplotlib.pyplot as plt
from IPython.display import Audio, display

from Utils import from_matrix_to_preset, denormalize_preset, pretty_print, get_audio, split_audio
import numpy as np
import matplotlib.pyplot as plt
from Optimizers import search_with_DE, search_with_CMA, evaluate_target, render_presets

# %%
audio_path = 'C:/Users/bryan/Documents/GitHub/Synth/exports/Violin_target.wav'
audio = get_audio(audio_path)

plt.plot(audio)
plt.show()
Audio(audio, rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_segments = split_audio(audio, prominence=0.06)

audio_segments = audio_segments[0:2]

for audio_segment in audio_segments:
    plt.plot(audio_segment)
    plt.show()
    display(Audio(audio_segment, rate=SAMPLE_RATE))

print('Pieces', len(audio_segments))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Pieces 1

# %%
estimated_presets = []
i = 1
last_best = None

if __name__ == '__main__':
    for audio_segment in audio_segments:
        print('Piece', i)
        target_C = evaluate_target(np.expand_dims(audio_segment, axis=0))
        duration = len(audio_segment) / SAMPLE_RATE
        if last_best is None:
            best, episodes_de = search_with_DE(target_C, duration, disp=True, maxiter=200)
            best, episodes_cma = search_with_CMA(target_C, duration, best)
            print(episodes_de, episodes_cma)
        else:
            best, _ = search_with_CMA(target_C, duration, last_best)

        last_best = best
        estimated_presets.append((best, duration))
        i+=1

        plt.plot(episodes_de, label='DE')
        plt.legend()
        plt.show()
        plt.plot(episodes_cma, label='CMA')
        plt.legend()
        plt.show()
# Out:
# Piece 1
# c:\Users\bryan\Documents\GitHub\Synth\venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:487: UserWarning: differential_evolution: the 'vectorized' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# differential_evolution step 1: f(x)= 0.19219282871953552
# differential_evolution step 2: f(x)= 0.19219282871953552
# differential_evolution step 3: f(x)= 0.19219282871953552
# differential_evolution step 4: f(x)= 0.19219282871953552
# differential_evolution step 5: f(x)= 0.19219282871953552
# differential_evolution step 6: f(x)= 0.19219282871953552
# differential_evolution step 7: f(x)= 0.1720024184007939
# differential_evolution step 8: f(x)= 0.1720024184007939
# differential_evolution step 9: f(x)= 0.1720024184007939
# differential_evolution step 10: f(x)= 0.1720024184007939
# differential_evolution step 11: f(x)= 0.1720024184007939
# differential_evolution step 12: f(x)= 0.1720024184007939
# differential_evolution step 13: f(x)= 0.1720024184007939
# differential_evolution step 14: f(x)= 0.1720024184007939
# differential_evolution step 15: f(x)= 0.1720024184007939
# differential_evolution step 16: f(x)= 0.1720024184007939
# differential_evolution step 17: f(x)= 0.1720024184007939
# differential_evolution step 18: f(x)= 0.1720024184007939
# differential_evolution step 19: f(x)= 0.1720024184007939
# differential_evolution step 20: f(x)= 0.1616062114613583
# differential_evolution step 21: f(x)= 0.1616062114613583
# differential_evolution step 22: f(x)= 0.1616062114613583
# differential_evolution step 23: f(x)= 0.1616062114613583
# differential_evolution step 24: f(x)= 0.1616062114613583
# differential_evolution step 25: f(x)= 0.1616062114613583
# differential_evolution step 26: f(x)= 0.1616062114613583
# differential_evolution step 27: f(x)= 0.1616062114613583
# differential_evolution step 28: f(x)= 0.1616062114613583
# differential_evolution step 29: f(x)= 0.1616062114613583
# differential_evolution step 30: f(x)= 0.1616062114613583
# differential_evolution step 31: f(x)= 0.1616062114613583
# differential_evolution step 32: f(x)= 0.1616062114613583
# differential_evolution step 33: f(x)= 0.1616062114613583
# differential_evolution step 34: f(x)= 0.1616062114613583
# differential_evolution step 35: f(x)= 0.1616062114613583
# differential_evolution step 36: f(x)= 0.15760936457172828
# differential_evolution step 37: f(x)= 0.15760936457172828
# differential_evolution step 38: f(x)= 0.15760936457172828
# differential_evolution step 39: f(x)= 0.15760936457172828
# differential_evolution step 40: f(x)= 0.1575804040264698
# differential_evolution step 41: f(x)= 0.1575804040264698
# differential_evolution step 42: f(x)= 0.1575804040264698
# differential_evolution step 43: f(x)= 0.1575804040264698
# differential_evolution step 44: f(x)= 0.1575804040264698
# differential_evolution step 45: f(x)= 0.1575804040264698
# differential_evolution step 46: f(x)= 0.1575804040264698
# differential_evolution step 47: f(x)= 0.1575804040264698
# differential_evolution step 48: f(x)= 0.1575804040264698
# differential_evolution step 49: f(x)= 0.1575804040264698
# differential_evolution step 50: f(x)= 0.1575804040264698
# differential_evolution step 51: f(x)= 0.1575804040264698
# differential_evolution step 52: f(x)= 0.1575804040264698
# differential_evolution step 53: f(x)= 0.1575804040264698
# differential_evolution step 54: f(x)= 0.1575804040264698
# differential_evolution step 55: f(x)= 0.1575804040264698
# differential_evolution step 56: f(x)= 0.1575804040264698
# differential_evolution step 57: f(x)= 0.1575804040264698
# differential_evolution step 58: f(x)= 0.15272145672259382
# differential_evolution step 59: f(x)= 0.15272145672259382
# differential_evolution step 60: f(x)= 0.15272145672259382
# differential_evolution step 61: f(x)= 0.15272145672259382
# differential_evolution step 62: f(x)= 0.15272145672259382
# differential_evolution step 63: f(x)= 0.15272145672259382
# differential_evolution step 64: f(x)= 0.15272145672259382
# differential_evolution step 65: f(x)= 0.15272145672259382
# differential_evolution step 66: f(x)= 0.15272145672259382
# differential_evolution step 67: f(x)= 0.15272145672259382
# differential_evolution step 68: f(x)= 0.15272145672259382
# differential_evolution step 69: f(x)= 0.15272145672259382
# differential_evolution step 70: f(x)= 0.15272145672259382
# differential_evolution step 71: f(x)= 0.15272145672259382
# differential_evolution step 72: f(x)= 0.15272145672259382
# differential_evolution step 73: f(x)= 0.15272145672259382
# differential_evolution step 74: f(x)= 0.15272145672259382
# differential_evolution step 75: f(x)= 0.15272145672259382
# differential_evolution step 76: f(x)= 0.15272145672259382
# differential_evolution step 77: f(x)= 0.15272145672259382
# differential_evolution step 78: f(x)= 0.15272145672259382
# differential_evolution step 79: f(x)= 0.15272145672259382
# differential_evolution step 80: f(x)= 0.15272145672259382
# differential_evolution step 81: f(x)= 0.14887487385191753
# differential_evolution step 82: f(x)= 0.14887487385191753
# differential_evolution step 83: f(x)= 0.14887487385191753
# differential_evolution step 84: f(x)= 0.14887487385191753
# differential_evolution step 85: f(x)= 0.14887487385191753
# differential_evolution step 86: f(x)= 0.14887487385191753
# differential_evolution step 87: f(x)= 0.14887487385191753
# differential_evolution step 88: f(x)= 0.14887487385191753
# differential_evolution step 89: f(x)= 0.14887487385191753
# differential_evolution step 90: f(x)= 0.14887487385191753
# differential_evolution step 91: f(x)= 0.14887487385191753
# differential_evolution step 92: f(x)= 0.14887487385191753
# differential_evolution step 93: f(x)= 0.14887487385191753
# differential_evolution step 94: f(x)= 0.14887487385191753
# differential_evolution step 95: f(x)= 0.14887487385191753
# differential_evolution step 96: f(x)= 0.14887487385191753
# differential_evolution step 97: f(x)= 0.14887487385191753
# differential_evolution step 98: f(x)= 0.14887487385191753
# differential_evolution step 99: f(x)= 0.14887487385191753
# differential_evolution step 100: f(x)= 0.14887487385191753
# differential_evolution step 101: f(x)= 0.14887487385191753
# differential_evolution step 102: f(x)= 0.14887487385191753
# differential_evolution step 103: f(x)= 0.14887487385191753
# differential_evolution step 104: f(x)= 0.14887487385191753
# differential_evolution step 105: f(x)= 0.14887487385191753
# differential_evolution step 106: f(x)= 0.14887487385191753
# differential_evolution step 107: f(x)= 0.14308709635478292
# differential_evolution step 108: f(x)= 0.14308709635478292
# differential_evolution step 109: f(x)= 0.14308709635478292
# differential_evolution step 110: f(x)= 0.14308709635478292
# differential_evolution step 111: f(x)= 0.13918048506611227
# differential_evolution step 112: f(x)= 0.13918048506611227
# differential_evolution step 113: f(x)= 0.13918048506611227
# differential_evolution step 114: f(x)= 0.13918048506611227
# differential_evolution step 115: f(x)= 0.13918048506611227
# differential_evolution step 116: f(x)= 0.13918048506611227
# differential_evolution step 117: f(x)= 0.13918048506611227
# differential_evolution step 118: f(x)= 0.13918048506611227
# differential_evolution step 119: f(x)= 0.13918048506611227
# differential_evolution step 120: f(x)= 0.13918048506611227
# differential_evolution step 121: f(x)= 0.13918048506611227
# differential_evolution step 122: f(x)= 0.13918048506611227
# differential_evolution step 123: f(x)= 0.13918048506611227
# differential_evolution step 124: f(x)= 0.13918048506611227
# differential_evolution step 125: f(x)= 0.13918048506611227
# differential_evolution step 126: f(x)= 0.13918048506611227
# differential_evolution step 127: f(x)= 0.13918048506611227
# differential_evolution step 128: f(x)= 0.13918048506611227
# differential_evolution step 129: f(x)= 0.13918048506611227
# differential_evolution step 130: f(x)= 0.13918048506611227
# differential_evolution step 131: f(x)= 0.13918048506611227
# differential_evolution step 132: f(x)= 0.13918048506611227
# differential_evolution step 133: f(x)= 0.13918048506611227
# differential_evolution step 134: f(x)= 0.13918048506611227
# differential_evolution step 135: f(x)= 0.13918048506611227
# differential_evolution step 136: f(x)= 0.13918048506611227
# differential_evolution step 137: f(x)= 0.13918048506611227
# differential_evolution step 138: f(x)= 0.13918048506611227
# differential_evolution step 139: f(x)= 0.13918048506611227
# differential_evolution step 140: f(x)= 0.13918048506611227
# differential_evolution step 141: f(x)= 0.13918048506611227
# differential_evolution step 142: f(x)= 0.13918048506611227
# differential_evolution step 143: f(x)= 0.13918048506611227
# differential_evolution step 144: f(x)= 0.13918048506611227
# differential_evolution step 145: f(x)= 0.13918048506611227
# differential_evolution step 146: f(x)= 0.13918048506611227
# differential_evolution step 147: f(x)= 0.13918048506611227
# differential_evolution step 148: f(x)= 0.13918048506611227
# differential_evolution step 149: f(x)= 0.13918048506611227
# differential_evolution step 150: f(x)= 0.13918048506611227
# differential_evolution step 151: f(x)= 0.13918048506611227
# differential_evolution step 152: f(x)= 0.13918048506611227
# differential_evolution step 153: f(x)= 0.13918048506611227
# differential_evolution step 154: f(x)= 0.13918048506611227
# differential_evolution step 155: f(x)= 0.13918048506611227
# differential_evolution step 156: f(x)= 0.13918048506611227
# differential_evolution step 157: f(x)= 0.13918048506611227
# differential_evolution step 158: f(x)= 0.13918048506611227
# differential_evolution step 159: f(x)= 0.13918048506611227
# differential_evolution step 160: f(x)= 0.13918048506611227
# differential_evolution step 161: f(x)= 0.13918048506611227
# differential_evolution step 162: f(x)= 0.13918048506611227
# differential_evolution step 163: f(x)= 0.13918048506611227
# differential_evolution step 164: f(x)= 0.13918048506611227
# differential_evolution step 165: f(x)= 0.13918048506611227
# differential_evolution step 166: f(x)= 0.13918048506611227
# differential_evolution step 167: f(x)= 0.12883932845878024
# differential_evolution step 168: f(x)= 0.12883932845878024
# differential_evolution step 169: f(x)= 0.12883932845878024
# differential_evolution step 170: f(x)= 0.12883932845878024
# differential_evolution step 171: f(x)= 0.12883932845878024
# differential_evolution step 172: f(x)= 0.12883932845878024
# differential_evolution step 173: f(x)= 0.12883932845878024
# differential_evolution step 174: f(x)= 0.12883932845878024
# differential_evolution step 175: f(x)= 0.12883932845878024
# differential_evolution step 176: f(x)= 0.12883932845878024
# differential_evolution step 177: f(x)= 0.12883932845878024
# differential_evolution step 178: f(x)= 0.12883932845878024
# differential_evolution step 179: f(x)= 0.12883932845878024
# differential_evolution step 180: f(x)= 0.12883932845878024
# differential_evolution step 181: f(x)= 0.12883932845878024
# differential_evolution step 182: f(x)= 0.12883932845878024
# differential_evolution step 183: f(x)= 0.12883932845878024
# differential_evolution step 184: f(x)= 0.12883932845878024
# differential_evolution step 185: f(x)= 0.12883932845878024
# differential_evolution step 186: f(x)= 0.12883932845878024
# differential_evolution step 187: f(x)= 0.12883932845878024
# differential_evolution step 188: f(x)= 0.12883932845878024
# differential_evolution step 189: f(x)= 0.12883932845878024
# differential_evolution step 190: f(x)= 0.12883932845878024
# differential_evolution step 191: f(x)= 0.12883932845878024
# differential_evolution step 192: f(x)= 0.12883932845878024
# differential_evolution step 193: f(x)= 0.12883932845878024
# differential_evolution step 194: f(x)= 0.12883932845878024
# differential_evolution step 195: f(x)= 0.12883932845878024
# differential_evolution step 196: f(x)= 0.12883932845878024
# differential_evolution step 197: f(x)= 0.12883932845878024
# differential_evolution step 198: f(x)= 0.12883932845878024
# differential_evolution step 199: f(x)= 0.12883932845878024
# differential_evolution step 200: f(x)= 0.12883932845878024
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=646571, Thu Mar 26 21:29:42 2026)
# NOTE (module=cma, iteration=621):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 4.4e+08 to 5.2e+01
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=711947, Thu Mar 26 21:33:33 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=644796, Thu Mar 26 21:36:20 2026)
# [np.float64(0.19209193413007647), np.float64(0.1914729892556609), np.float64(0.19200486848876175), np.float64(0.19148206678423774), np.float64(0.19270179039072008), np.float64(0.19172165306621453), np.float64(0.17173849033938557), np.float64(0.17177137559379865), np.float64(0.17190931999211503), np.float64(0.1720005060299539), np.float64(0.1719584917220288), np.float64(0.1717686683573775), np.float64(0.17192923933922138), np.float64(0.17198299414236148), np.float64(0.1716541946409965), np.float64(0.172031715224559), np.float64(0.17227188134347068), np.float64(0.17181118391543704), np.float64(0.17207105054426686), np.float64(0.1608870266666567), np.float64(0.16027305175474676), np.float64(0.16042517621090913), np.float64(0.1610828005908039), np.float64(0.16142787434228204), np.float64(0.16137739615169858), np.float64(0.16124740096028073), np.float64(0.1618228140561067), np.float64(0.1619739292923069), np.float64(0.1613721782579734), np.float64(0.1598579431485661), np.float64(0.1612299430966503), np.float64(0.16226847907617023), np.float64(0.1622951014720994), np.float64(0.16206099010216324), np.float64(0.16069382139026336), np.float64(0.1578559076489351), np.float64(0.1574782090261721), np.float64(0.1577230072053834), np.float64(0.15773374645156887), np.float64(0.15723498243536135), np.float64(0.1574847774045858), np.float64(0.15779985325478119), np.float64(0.15832463137861402), np.float64(0.15836921216467686), np.float64(0.15794638706655406), np.float64(0.15808172951544563), np.float64(0.1579206506063462), np.float64(0.15758915257571376), np.float64(0.15845150544196707), np.float64(0.15791628689557774), np.float64(0.15789020509118631), np.float64(0.15849805694053076), np.float64(0.15817475181107699), np.float64(0.1578478332379133), np.float64(0.15741654545828376), np.float64(0.15827613328310894), np.float64(0.15765232003401614), np.float64(0.1528497060954273), np.float64(0.1528024426903794), np.float64(0.15274227156903722), np.float64(0.15276318828752827), np.float64(0.1527494105485264), np.float64(0.15263815316988485), np.float64(0.1528029608429608), np.float64(0.1530464217262623), np.float64(0.15271569251633219), np.float64(0.15266693870105777), np.float64(0.15295355848247863), np.float64(0.15281630530356485), np.float64(0.15289416930968946), np.float64(0.1529338142111859), np.float64(0.1528299277955424), np.float64(0.15264099022153435), np.float64(0.1528526315344411), np.float64(0.15269266861924344), np.float64(0.1526259966931857), np.float64(0.1526339726028219), np.float64(0.15249696223036766), np.float64(0.1529114805368916), np.float64(0.15255318527527392), np.float64(0.1476246015689997), np.float64(0.1471966881373431), np.float64(0.14907338981877774), np.float64(0.14893656862802043), np.float64(0.1479093681787724), np.float64(0.14808438999025023), np.float64(0.14788740475981935), np.float64(0.14825016915419192), np.float64(0.1480308907095614), np.float64(0.14767822490498225), np.float64(0.14800039490358977), np.float64(0.14791949523764505), np.float64(0.14840995880156813), np.float64(0.14807075895890248), np.float64(0.1471279027448832), np.float64(0.14883052566288194), np.float64(0.14860300803208343), np.float64(0.1480623199276266), np.float64(0.14780780876513924), np.float64(0.14813115888561934), np.float64(0.14781453937633676), np.float64(0.14769584260724228), np.float64(0.14818636977338845), np.float64(0.14854908775198736), np.float64(0.14783528810253993), np.float64(0.14823203794054507), np.float64(0.14321515441186572), np.float64(0.14337518898221965), np.float64(0.14318707772528264), np.float64(0.1429121685765742), np.float64(0.1391533249678082), np.float64(0.13879626997147199), np.float64(0.13883307595532876), np.float64(0.1387223813109779), np.float64(0.13893230913219684), np.float64(0.1393624785115553), np.float64(0.1390553082723838), np.float64(0.13907915399321588), np.float64(0.13924529469185026), np.float64(0.13928088047472115), np.float64(0.13932843735750802), np.float64(0.1389571321866818), np.float64(0.1394 ...

# %%
predicted_joined_audio = []

for preset, duration in estimated_presets:
    preset = np.expand_dims(preset, axis=0)
    # error = evaluate_presets((denormalize_preset(from_matrix_to_preset(preset)), target_C, duration))
    # print('Error', error)
    # target_audio = np.expand_dims(audio_segments[0], axis=0)
    predicted_audio = render_presets(denormalize_preset(from_matrix_to_preset(preset)), duration)
    predicted_joined_audio.append(predicted_audio[0])

    denormalized_predicted_preset = denormalize_preset(from_matrix_to_preset(preset))
    pretty_print(denormalized_predicted_preset)

predicted_joined_audio = np.concatenate(predicted_joined_audio, axis=0)

print(min(episodes_cma))
# Out:
# {
#   osc1_shape:   [
#     2.011234377350833
#   ]
#   osc1_phase:   [
#     0.5084964723647123
#   ]
#   osc1_volume:   [
#     0.8569038192335828
#   ]
#   osc1_freq:   [
#     658.2089542677003
#   ]
#   osc2_shape:   [
#     0.18603544442548528
#   ]
#   osc2_phase:   [
#     0.1807133319326668
#   ]
#   osc2_volume:   [
#     0.8469177889894028
#   ]
#   osc2_freq:   [
#     10463.275194261758
#   ]
#   osc3_shape:   [
#     0.6007268941434629
#   ]
#   osc3_phase:   [
#     0.27334506313943374
#   ]
#   osc3_volume:   [
#     0.9652953103724161
#   ]
#   osc3_freq:   [
#     665.77025938878
#   ]
#   osc4_shape:   [
#     3.988726165198248
#   ]
#   osc4_phase:   [
#     0.5287978277860366
#   ]
#   osc4_volume:   [
#     0.001845664001994006
#   ]
#   osc4_freq:   [
#     19286.60790044683
#   ]
#   oscnoise_volume:   [
#     0.02061708924612289
#   ]
#   filter_envelope_attack:   [
#     0.1340581078632512
#   ]
#   filter_envelope_decay:   [
#     0.16339858813742048
#   ]
#   filter_envelope_sustain:   [
#     0.999783339516662
#   ]
#   filter_envelope_release:   [
#     0.04670735153417614
#   ]
#   base_cutoff_hz:   [
#     2763.7757046459965
#   ]
#   filter_type:   [
#     1.3447795931150266
#   ]
#   base_q:   [
#     17.103788694027447
#   ]
#   envelope_depth:   [
#     0.12354218352919608
#   ]
#   envelope_attack:   [
#     0.11227711730936518
#   ]
#   envelope_decay:   [
#     0.007516182849596393
#   ]
#   envelope_sustain:   [
#     0.36522939371793384
#   ]
#   envelope_release:   [
#     0.15981947255759993
#   ]
# }
# 0.07290292163386368

# %%
spect = evaluate_target(np.array([audio[:120000]]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(audio[:120000], rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spect = evaluate_target(np.array([predicted_joined_audio]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(predicted_joined_audio, rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
