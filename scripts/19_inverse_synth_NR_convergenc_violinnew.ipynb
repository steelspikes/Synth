# %%
import os

# Subir un nivel respecto a la carpeta actual
os.chdir("..")

import numpy as np
from globals import SAMPLE_RATE
import librosa
import matplotlib.pyplot as plt
from IPython.display import Audio, display

from Utils import from_matrix_to_preset, denormalize_preset, pretty_print, get_audio, split_audio
import numpy as np
import matplotlib.pyplot as plt
from Optimizers import search_with_DE, search_with_CMA, evaluate_target, render_presets

# %%
audio_path = 'C:/Users/bryan/Documents/GitHub/Synth/exports/Violin_target.wav'
audio = get_audio(audio_path)

plt.plot(audio)
plt.show()
Audio(audio, rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_segments = split_audio(audio, prominence=0.06)

audio_segments = audio_segments[0:2]

for audio_segment in audio_segments:
    plt.plot(audio_segment)
    plt.show()
    display(Audio(audio_segment, rate=SAMPLE_RATE))

print('Pieces', len(audio_segments))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Pieces 1

# %%
estimated_presets = []
i = 1
last_best = None

if __name__ == '__main__':
    for audio_segment in audio_segments:
        print('Piece', i)
        target_C = evaluate_target(np.expand_dims(audio_segment, axis=0))
        duration = len(audio_segment) / SAMPLE_RATE
        if last_best is None:
            best, episodes_de = search_with_DE(target_C, duration, disp=True, maxiter=200)
            best, episodes_cma = search_with_CMA(target_C, duration, best)
            print(episodes_de, episodes_cma)
        else:
            best, _ = search_with_CMA(target_C, duration, last_best)

        last_best = best
        estimated_presets.append((best, duration))
        i+=1

        plt.plot(episodes_de, label='DE')
        plt.legend()
        plt.show()
        plt.plot(episodes_cma, label='CMA')
        plt.legend()
        plt.show()
# Out:
# Piece 1
# c:\Users\bryan\Documents\GitHub\Synth\venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:487: UserWarning: differential_evolution: the 'vectorized' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# differential_evolution step 1: f(x)= 0.2020966295802113
# differential_evolution step 2: f(x)= 0.2020966295802113
# differential_evolution step 3: f(x)= 0.2020966295802113
# differential_evolution step 4: f(x)= 0.2020966295802113
# differential_evolution step 5: f(x)= 0.1956817729667075
# differential_evolution step 6: f(x)= 0.18513519403616918
# differential_evolution step 7: f(x)= 0.18513519403616918
# differential_evolution step 8: f(x)= 0.18513519403616918
# differential_evolution step 9: f(x)= 0.18513519403616918
# differential_evolution step 10: f(x)= 0.16213413599193408
# differential_evolution step 11: f(x)= 0.16213413599193408
# differential_evolution step 12: f(x)= 0.16213413599193408
# differential_evolution step 13: f(x)= 0.16213413599193408
# differential_evolution step 14: f(x)= 0.16213413599193408
# differential_evolution step 15: f(x)= 0.16213413599193408
# differential_evolution step 16: f(x)= 0.16213413599193408
# differential_evolution step 17: f(x)= 0.16213413599193408
# differential_evolution step 18: f(x)= 0.16213413599193408
# differential_evolution step 19: f(x)= 0.16213413599193408
# differential_evolution step 20: f(x)= 0.16213413599193408
# differential_evolution step 21: f(x)= 0.16213413599193408
# differential_evolution step 22: f(x)= 0.16213413599193408
# differential_evolution step 23: f(x)= 0.16213413599193408
# differential_evolution step 24: f(x)= 0.16213413599193408
# differential_evolution step 25: f(x)= 0.16213413599193408
# differential_evolution step 26: f(x)= 0.16213413599193408
# differential_evolution step 27: f(x)= 0.16213413599193408
# differential_evolution step 28: f(x)= 0.16213413599193408
# differential_evolution step 29: f(x)= 0.16213413599193408
# differential_evolution step 30: f(x)= 0.16213413599193408
# differential_evolution step 31: f(x)= 0.16213413599193408
# differential_evolution step 32: f(x)= 0.16213413599193408
# differential_evolution step 33: f(x)= 0.16213413599193408
# differential_evolution step 34: f(x)= 0.16213413599193408
# differential_evolution step 35: f(x)= 0.16213413599193408
# differential_evolution step 36: f(x)= 0.15717155923570808
# differential_evolution step 37: f(x)= 0.15717155923570808
# differential_evolution step 38: f(x)= 0.15717155923570808
# differential_evolution step 39: f(x)= 0.15717155923570808
# differential_evolution step 40: f(x)= 0.15717155923570808
# differential_evolution step 41: f(x)= 0.15717155923570808
# differential_evolution step 42: f(x)= 0.15717155923570808
# differential_evolution step 43: f(x)= 0.15717155923570808
# differential_evolution step 44: f(x)= 0.15717155923570808
# differential_evolution step 45: f(x)= 0.15717155923570808
# differential_evolution step 46: f(x)= 0.15717155923570808
# differential_evolution step 47: f(x)= 0.15717155923570808
# differential_evolution step 48: f(x)= 0.15717155923570808
# differential_evolution step 49: f(x)= 0.15717155923570808
# differential_evolution step 50: f(x)= 0.15473309262635968
# differential_evolution step 51: f(x)= 0.15473309262635968
# differential_evolution step 52: f(x)= 0.15473309262635968
# differential_evolution step 53: f(x)= 0.15473309262635968
# differential_evolution step 54: f(x)= 0.15473309262635968
# differential_evolution step 55: f(x)= 0.15473309262635968
# differential_evolution step 56: f(x)= 0.15473309262635968
# differential_evolution step 57: f(x)= 0.15379045345986603
# differential_evolution step 58: f(x)= 0.15379045345986603
# differential_evolution step 59: f(x)= 0.15379045345986603
# differential_evolution step 60: f(x)= 0.15379045345986603
# differential_evolution step 61: f(x)= 0.15379045345986603
# differential_evolution step 62: f(x)= 0.15379045345986603
# differential_evolution step 63: f(x)= 0.15379045345986603
# differential_evolution step 64: f(x)= 0.15379045345986603
# differential_evolution step 65: f(x)= 0.15379045345986603
# differential_evolution step 66: f(x)= 0.15379045345986603
# differential_evolution step 67: f(x)= 0.15379045345986603
# differential_evolution step 68: f(x)= 0.15379045345986603
# differential_evolution step 69: f(x)= 0.15379045345986603
# differential_evolution step 70: f(x)= 0.15379045345986603
# differential_evolution step 71: f(x)= 0.15379045345986603
# differential_evolution step 72: f(x)= 0.15379045345986603
# differential_evolution step 73: f(x)= 0.15379045345986603
# differential_evolution step 74: f(x)= 0.15379045345986603
# differential_evolution step 75: f(x)= 0.15379045345986603
# differential_evolution step 76: f(x)= 0.15379045345986603
# differential_evolution step 77: f(x)= 0.15379045345986603
# differential_evolution step 78: f(x)= 0.15379045345986603
# differential_evolution step 79: f(x)= 0.15379045345986603
# differential_evolution step 80: f(x)= 0.15379045345986603
# differential_evolution step 81: f(x)= 0.15379045345986603
# differential_evolution step 82: f(x)= 0.15379045345986603
# differential_evolution step 83: f(x)= 0.15379045345986603
# differential_evolution step 84: f(x)= 0.15379045345986603
# differential_evolution step 85: f(x)= 0.15379045345986603
# differential_evolution step 86: f(x)= 0.15379045345986603
# differential_evolution step 87: f(x)= 0.15379045345986603
# differential_evolution step 88: f(x)= 0.15379045345986603
# differential_evolution step 89: f(x)= 0.15379045345986603
# differential_evolution step 90: f(x)= 0.15379045345986603
# differential_evolution step 91: f(x)= 0.15379045345986603
# differential_evolution step 92: f(x)= 0.15379045345986603
# differential_evolution step 93: f(x)= 0.15379045345986603
# differential_evolution step 94: f(x)= 0.15379045345986603
# differential_evolution step 95: f(x)= 0.15379045345986603
# differential_evolution step 96: f(x)= 0.15379045345986603
# differential_evolution step 97: f(x)= 0.15379045345986603
# differential_evolution step 98: f(x)= 0.15379045345986603
# differential_evolution step 99: f(x)= 0.15379045345986603
# differential_evolution step 100: f(x)= 0.15379045345986603
# differential_evolution step 101: f(x)= 0.15379045345986603
# differential_evolution step 102: f(x)= 0.15379045345986603
# differential_evolution step 103: f(x)= 0.15379045345986603
# differential_evolution step 104: f(x)= 0.15379045345986603
# differential_evolution step 105: f(x)= 0.15379045345986603
# differential_evolution step 106: f(x)= 0.15379045345986603
# differential_evolution step 107: f(x)= 0.15379045345986603
# differential_evolution step 108: f(x)= 0.15379045345986603
# differential_evolution step 109: f(x)= 0.15379045345986603
# differential_evolution step 110: f(x)= 0.15379045345986603
# differential_evolution step 111: f(x)= 0.15379045345986603
# differential_evolution step 112: f(x)= 0.15379045345986603
# differential_evolution step 113: f(x)= 0.15379045345986603
# differential_evolution step 114: f(x)= 0.1330452432281468
# differential_evolution step 115: f(x)= 0.1330452432281468
# differential_evolution step 116: f(x)= 0.1330452432281468
# differential_evolution step 117: f(x)= 0.1330452432281468
# differential_evolution step 118: f(x)= 0.1330452432281468
# differential_evolution step 119: f(x)= 0.1330452432281468
# differential_evolution step 120: f(x)= 0.1330452432281468
# differential_evolution step 121: f(x)= 0.1330452432281468
# differential_evolution step 122: f(x)= 0.1330452432281468
# differential_evolution step 123: f(x)= 0.1330452432281468
# differential_evolution step 124: f(x)= 0.1330452432281468
# differential_evolution step 125: f(x)= 0.1330452432281468
# differential_evolution step 126: f(x)= 0.1330452432281468
# differential_evolution step 127: f(x)= 0.1330452432281468
# differential_evolution step 128: f(x)= 0.1330452432281468
# differential_evolution step 129: f(x)= 0.1330452432281468
# differential_evolution step 130: f(x)= 0.1330452432281468
# differential_evolution step 131: f(x)= 0.1330452432281468
# differential_evolution step 132: f(x)= 0.1330452432281468
# differential_evolution step 133: f(x)= 0.1330452432281468
# differential_evolution step 134: f(x)= 0.1330452432281468
# differential_evolution step 135: f(x)= 0.1330452432281468
# differential_evolution step 136: f(x)= 0.1330452432281468
# differential_evolution step 137: f(x)= 0.1330452432281468
# differential_evolution step 138: f(x)= 0.1330452432281468
# differential_evolution step 139: f(x)= 0.1330452432281468
# differential_evolution step 140: f(x)= 0.1330452432281468
# differential_evolution step 141: f(x)= 0.1330452432281468
# differential_evolution step 142: f(x)= 0.1330452432281468
# differential_evolution step 143: f(x)= 0.1330452432281468
# differential_evolution step 144: f(x)= 0.1330452432281468
# differential_evolution step 145: f(x)= 0.1330452432281468
# differential_evolution step 146: f(x)= 0.1330452432281468
# differential_evolution step 147: f(x)= 0.1330452432281468
# differential_evolution step 148: f(x)= 0.1330452432281468
# differential_evolution step 149: f(x)= 0.1330452432281468
# differential_evolution step 150: f(x)= 0.1330452432281468
# differential_evolution step 151: f(x)= 0.1330452432281468
# differential_evolution step 152: f(x)= 0.1330452432281468
# differential_evolution step 153: f(x)= 0.1330452432281468
# differential_evolution step 154: f(x)= 0.1330452432281468
# differential_evolution step 155: f(x)= 0.1330452432281468
# differential_evolution step 156: f(x)= 0.1330452432281468
# differential_evolution step 157: f(x)= 0.1330452432281468
# differential_evolution step 158: f(x)= 0.1330452432281468
# differential_evolution step 159: f(x)= 0.1330452432281468
# differential_evolution step 160: f(x)= 0.1330452432281468
# differential_evolution step 161: f(x)= 0.1330452432281468
# differential_evolution step 162: f(x)= 0.1330452432281468
# differential_evolution step 163: f(x)= 0.1330452432281468
# differential_evolution step 164: f(x)= 0.1330452432281468
# differential_evolution step 165: f(x)= 0.1330452432281468
# differential_evolution step 166: f(x)= 0.1330452432281468
# differential_evolution step 167: f(x)= 0.1330452432281468
# differential_evolution step 168: f(x)= 0.1330452432281468
# differential_evolution step 169: f(x)= 0.1330452432281468
# differential_evolution step 170: f(x)= 0.1330452432281468
# differential_evolution step 171: f(x)= 0.1330452432281468
# differential_evolution step 172: f(x)= 0.1330452432281468
# differential_evolution step 173: f(x)= 0.1330452432281468
# differential_evolution step 174: f(x)= 0.1330452432281468
# differential_evolution step 175: f(x)= 0.1330452432281468
# differential_evolution step 176: f(x)= 0.1330452432281468
# differential_evolution step 177: f(x)= 0.1330452432281468
# differential_evolution step 178: f(x)= 0.1330452432281468
# differential_evolution step 179: f(x)= 0.1330452432281468
# differential_evolution step 180: f(x)= 0.1330452432281468
# differential_evolution step 181: f(x)= 0.1330452432281468
# differential_evolution step 182: f(x)= 0.1330452432281468
# differential_evolution step 183: f(x)= 0.1330452432281468
# differential_evolution step 184: f(x)= 0.1330452432281468
# differential_evolution step 185: f(x)= 0.1330452432281468
# differential_evolution step 186: f(x)= 0.1330452432281468
# differential_evolution step 187: f(x)= 0.1330452432281468
# differential_evolution step 188: f(x)= 0.1330452432281468
# differential_evolution step 189: f(x)= 0.1330452432281468
# differential_evolution step 190: f(x)= 0.1330452432281468
# differential_evolution step 191: f(x)= 0.1330452432281468
# differential_evolution step 192: f(x)= 0.1330452432281468
# differential_evolution step 193: f(x)= 0.1330452432281468
# differential_evolution step 194: f(x)= 0.1330452432281468
# differential_evolution step 195: f(x)= 0.1330452432281468
# differential_evolution step 196: f(x)= 0.1330452432281468
# differential_evolution step 197: f(x)= 0.1330452432281468
# differential_evolution step 198: f(x)= 0.1330452432281468
# differential_evolution step 199: f(x)= 0.1330452432281468
# differential_evolution step 200: f(x)= 0.1330452432281468
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=707574, Fri Mar 27 21:35:39 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=735327, Fri Mar 27 21:39:50 2026)
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=802886, Fri Mar 27 21:43:03 2026)
# [np.float64(0.20203281811604942), np.float64(0.20229176940207463), np.float64(0.2025257263347088), np.float64(0.2017415289119834), np.float64(0.1963715144539119), np.float64(0.18382780922819916), np.float64(0.18460345562533195), np.float64(0.18564048934578847), np.float64(0.1841000448984396), np.float64(0.16280070244915085), np.float64(0.1631869173731495), np.float64(0.16258484515107668), np.float64(0.16255154736779548), np.float64(0.16261639915677448), np.float64(0.16214354979080922), np.float64(0.16338814354846565), np.float64(0.16315662731141833), np.float64(0.16281580074625165), np.float64(0.1628262159389248), np.float64(0.16281875033603316), np.float64(0.1624744167669726), np.float64(0.16255900638862567), np.float64(0.1621218778684427), np.float64(0.16186601068118506), np.float64(0.1624421448643677), np.float64(0.16260317457890996), np.float64(0.16277520839975132), np.float64(0.16293989045923557), np.float64(0.1623658558345734), np.float64(0.16218827628448898), np.float64(0.16198835697661637), np.float64(0.16279740204080795), np.float64(0.16230894208260477), np.float64(0.16220527370087914), np.float64(0.16246624348401487), np.float64(0.1584759603061442), np.float64(0.15793510597040286), np.float64(0.1576876505195743), np.float64(0.15775805257646225), np.float64(0.15778775367694214), np.float64(0.15782217065772758), np.float64(0.157739167273547), np.float64(0.15834682326529698), np.float64(0.157843249384847), np.float64(0.157095202851677), np.float64(0.15806161427042742), np.float64(0.15751741000886263), np.float64(0.15730674666912348), np.float64(0.1577944656605998), np.float64(0.15519553630996938), np.float64(0.1541195149383106), np.float64(0.15441675814965183), np.float64(0.15433278419444962), np.float64(0.15469508785869307), np.float64(0.15467609867669846), np.float64(0.15413544359339265), np.float64(0.1539240868608646), np.float64(0.1544558197152315), np.float64(0.153933507735406), np.float64(0.15466217399223736), np.float64(0.15449923380727587), np.float64(0.1543681349827932), np.float64(0.154107563697676), np.float64(0.15406545411619507), np.float64(0.15489721836680853), np.float64(0.15328659401713055), np.float64(0.15356514913021718), np.float64(0.15419885754112797), np.float64(0.15408625988461574), np.float64(0.15317036936197956), np.float64(0.15403745634518212), np.float64(0.15371277545641612), np.float64(0.15441060793665295), np.float64(0.15386822881783235), np.float64(0.1543598732453895), np.float64(0.15396505807994218), np.float64(0.1543233291801256), np.float64(0.15368493893341048), np.float64(0.15392066833016696), np.float64(0.1548145095162866), np.float64(0.15484339084439747), np.float64(0.15467036437894494), np.float64(0.15418009689109347), np.float64(0.15435911571933633), np.float64(0.154618244666788), np.float64(0.154158262799806), np.float64(0.15432809691948976), np.float64(0.15422470932574625), np.float64(0.15415965827168618), np.float64(0.15362777783647796), np.float64(0.1533885984390451), np.float64(0.15423432641831775), np.float64(0.15431172930231057), np.float64(0.15495950811563403), np.float64(0.15420975524361064), np.float64(0.15386050844365765), np.float64(0.15393141509366326), np.float64(0.15446573511107733), np.float64(0.15429981036926774), np.float64(0.15342291691441481), np.float64(0.15435971339148055), np.float64(0.15480638421930368), np.float64(0.153872584217745), np.float64(0.15408598960104927), np.float64(0.15363672425458336), np.float64(0.15459972113354997), np.float64(0.15376423851511284), np.float64(0.15380883000292517), np.float64(0.15471574381030948), np.float64(0.15394425358591135), np.float64(0.15385662629019234), np.float64(0.1530032993173368), np.float64(0.1536428315306578), np.float64(0.13338404864204675), np.float64(0.1331297238182942), np.float64(0.1326721019228604), np.float64(0.13329712219810433), np.float64(0.133565232215884), np.float64(0.13317035956627812), np.float64(0.13343778708107637), np.float64(0.13311507738360687), np.float64(0.1330182924565401), np.float64(0.1336 ...

# %%
predicted_joined_audio = []

for preset, duration in estimated_presets:
    preset = np.expand_dims(preset, axis=0)
    # error = evaluate_presets((denormalize_preset(from_matrix_to_preset(preset)), target_C, duration))
    # print('Error', error)
    # target_audio = np.expand_dims(audio_segments[0], axis=0)
    predicted_audio = render_presets(denormalize_preset(from_matrix_to_preset(preset)), duration)
    predicted_joined_audio.append(predicted_audio[0])

    denormalized_predicted_preset = denormalize_preset(from_matrix_to_preset(preset))
    pretty_print(denormalized_predicted_preset)

predicted_joined_audio = np.concatenate(predicted_joined_audio, axis=0)

print(min(episodes_cma))
# Out:
# {
#   osc1_shape:   [
#     1.107585809040453
#   ]
#   osc1_phase:   [
#     0.24333725539773207
#   ]
#   osc1_volume:   [
#     3.2188121039454044e-05
#   ]
#   osc1_freq:   [
#     932.173488527401
#   ]
#   osc2_shape:   [
#     1.1037308325513844
#   ]
#   osc2_phase:   [
#     0.44049823434122015
#   ]
#   osc2_volume:   [
#     0.8100396077765956
#   ]
#   osc2_freq:   [
#     657.5141634408546
#   ]
#   osc3_shape:   [
#     0.09109697899005621
#   ]
#   osc3_phase:   [
#     0.7167454033959845
#   ]
#   osc3_volume:   [
#     0.12232632795172932
#   ]
#   osc3_freq:   [
#     3945.0718705857535
#   ]
#   osc4_shape:   [
#     0.438572744745086
#   ]
#   osc4_phase:   [
#     0.6392693290271375
#   ]
#   osc4_volume:   [
#     0.07372350345193497
#   ]
#   osc4_freq:   [
#     3304.769178721961
#   ]
#   oscnoise_volume:   [
#     0.00012938020006522208
#   ]
#   filter_envelope_attack:   [
#     0.16882047620921883
#   ]
#   filter_envelope_decay:   [
#     0.18038425990337636
#   ]
#   filter_envelope_sustain:   [
#     0.6303624426450526
#   ]
#   filter_envelope_release:   [
#     0.36793380078479393
#   ]
#   base_cutoff_hz:   [
#     3256.153454372424
#   ]
#   filter_type:   [
#     1.0089061281429357
#   ]
#   base_q:   [
#     0.7295597572735447
#   ]
#   envelope_depth:   [
#     0.003994427379030343
#   ]
#   envelope_attack:   [
#     0.17004274475799638
#   ]
#   envelope_decay:   [
#     0.0924382581263521
#   ]
#   envelope_sustain:   [
#     0.6541994365830713
#   ]
#   envelope_release:   [
#     0.4939364125473702
#   ]
# }
# 0.08361740029611614

# %%
spect = evaluate_target(np.array([audio[:120000]]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(audio[:120000], rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spect = evaluate_target(np.array([predicted_joined_audio]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(predicted_joined_audio, rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
