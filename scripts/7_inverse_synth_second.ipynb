# %%
import os

# Subir un nivel respecto a la carpeta actual
os.chdir("..")

import numpy as np
from globals import SAMPLE_RATE, PROCESSORS
import librosa
import matplotlib.pyplot as plt
from IPython.display import Audio, display
from scipy.signal import find_peaks

from Utils import load_parameters_file, from_matrix_to_preset, MSE, denormalize_preset, normalize_preset, pretty_print, PARAM_NAMES, from_preset_to_matrix, mel_spectrogram, mfcc, spectrogram
from Synth import Synth
import numpy as np
import cma
import matplotlib.pyplot as plt
from multiprocessing import Pool
from parallelEvaluation import evaluate_presets
from scipy.optimize import differential_evolution

# %%
def get_audio(audio_path):
    y, _sr = librosa.load(audio_path, sr=SAMPLE_RATE)
    y = np.array(y, dtype=np.float64)
    y, _ = librosa.effects.trim(y, top_db=15)

    rms_target = 0.1
    rms_actual = np.sqrt(np.mean(y**2))
    scale = rms_target / (rms_actual + 1e-8)
    return y * scale

def split_audio(audio, prominence=0.01):
    win_size = int(0.02 * SAMPLE_RATE)

    rectified_signal = np.abs(audio)
    window = np.ones(win_size) / win_size
    envelope = np.convolve(rectified_signal, window, mode='same')

    minimals, _ = find_peaks(-envelope, prominence=prominence)
    minimals = np.concatenate((np.array([0]), minimals))

    minimals = minimals + (win_size // 2)

    audios = []
    
    for i in range(minimals.shape[0]):
        if i < minimals.shape[0] - 1:
            audios.append(audio[minimals[i] : minimals[i+1]])
        else:
            audios.append(audio[minimals[i]:])

    return audios

# %%
def render_presets(presets, duration=0):
    synth = Synth(
        sample_rate=SAMPLE_RATE,
        duration=duration,
        presets=presets
    )
    return synth.process_audio().astype(np.float64)

def evaluate_target(audio):
    return mel_spectrogram(audio, sr=SAMPLE_RATE, n_fft=2048, hop_length=256, n_mels=128)

# %%
def search_with_DE(target_C, duration):
    bounds = [(0, 1)] * len(PARAM_NAMES)

    with Pool(PROCESSORS) as pool:
        def get_fitness(solutions):
            solutions = np.array(solutions).T
            solutions_splitted = np.array_split(solutions, PROCESSORS)
            presets_splitted = [(denormalize_preset(from_matrix_to_preset(chunk)), target_C, duration) for chunk in solutions_splitted]
            
            solutions_evaluated = pool.map(evaluate_presets, presets_splitted)
            return np.concatenate(solutions_evaluated).tolist()
            
        result = differential_evolution(
            get_fitness,
            bounds=bounds,
            popsize=10,        # 10 × n_params individuos
            mutation=(0.5, 1),
            recombination=0.7,
            tol=1e-4,
            maxiter=120,
            polish=False,
            seed=None,
            disp=True,
            workers=1,
            vectorized=True
        )

        x_best = result.x
        f_best = result.fun

        return x_best

# %%
def search_with_CMA(target_C, duration, x0):
    sigma0 = 0.05

    with Pool(PROCESSORS) as pool:
        def get_fitness(solutions):
            solutions = np.array(solutions)
            solutions_splitted = np.array_split(solutions, PROCESSORS)
            presets_splitted = [(denormalize_preset(from_matrix_to_preset(chunk)), target_C, duration) for chunk in solutions_splitted]
            
            solutions_evaluated = pool.map(evaluate_presets, presets_splitted)
            return np.concatenate(solutions_evaluated)

        options = {
            'popsize': 30,
            'bounds': [np.zeros_like(x0), np.ones_like(x0)],
            'tolfun': 1e-8,
            'tolx': 1e-8,
            'maxiter': 1000
        }

        es = cma.CMAEvolutionStrategy(x0, sigma0, options)
        gen = 1

        while not es.stop():
            solutions = np.array(es.ask())  # devuelve una lista de individuos

            fitnesses = get_fitness(solutions)

            best_idx = np.argmin(fitnesses)          # índice del mejor fitness
            best_fitness = fitnesses[best_idx]       # fitness correspondiente

            if gen % 100 == 0:
                print("Gen", gen, "Mejor fitness:", best_fitness, "Sigma", es.sigma, "Restart")

            es.tell(solutions, fitnesses)  # pasar fitness al algoritmo

            gen += 1

        return es.best

# %%
audio_path = 'C:/Users/bryan/Documents/GitHub/Synth/presets/Recorder.mp3'
audio = get_audio(audio_path)[:90000] # Quitar esto

plt.plot(audio)
plt.show()
Audio(audio, rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_segments = split_audio(audio, prominence=0.09)

for audio_segment in audio_segments:
    plt.plot(audio_segment)
    plt.show()
    display(Audio(audio_segment, rate=SAMPLE_RATE))

print('Pieces', len(audio_segments))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Pieces 3

# %%
estimated_presets = []

if __name__ == '__main__':
    for audio_segment in audio_segments:
        target_C = evaluate_target(np.expand_dims(audio_segment, axis=0))
        duration = len(audio_segment) / SAMPLE_RATE
        best = search_with_DE(target_C, duration)
        best = search_with_CMA(target_C, duration, best)
        estimated_presets.append((best.x, duration))
# Out:
# c:\Users\bryan\Documents\GitHub\Synth\venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:487: UserWarning: differential_evolution: the 'vectorized' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# differential_evolution step 1: f(x)= 0.09982033230161788
# differential_evolution step 2: f(x)= 0.09982033230161788
# differential_evolution step 3: f(x)= 0.09982033230161788
# differential_evolution step 4: f(x)= 0.09982033230161788
# differential_evolution step 5: f(x)= 0.09982033230161788
# differential_evolution step 6: f(x)= 0.0946663915273074
# differential_evolution step 7: f(x)= 0.0946663915273074
# differential_evolution step 8: f(x)= 0.0946663915273074
# differential_evolution step 9: f(x)= 0.09389540207064243
# differential_evolution step 10: f(x)= 0.09389540207064243
# differential_evolution step 11: f(x)= 0.09389540207064243
# differential_evolution step 12: f(x)= 0.09389540207064243
# differential_evolution step 13: f(x)= 0.0907605655827991
# differential_evolution step 14: f(x)= 0.0907605655827991
# differential_evolution step 15: f(x)= 0.0907605655827991
# differential_evolution step 16: f(x)= 0.0907605655827991
# differential_evolution step 17: f(x)= 0.0907605655827991
# differential_evolution step 18: f(x)= 0.0907605655827991
# differential_evolution step 19: f(x)= 0.0907605655827991
# differential_evolution step 20: f(x)= 0.0907605655827991
# differential_evolution step 21: f(x)= 0.0907605655827991
# differential_evolution step 22: f(x)= 0.0907605655827991
# differential_evolution step 23: f(x)= 0.0907605655827991
# differential_evolution step 24: f(x)= 0.0907605655827991
# differential_evolution step 25: f(x)= 0.0907605655827991
# differential_evolution step 26: f(x)= 0.08984529269891706
# differential_evolution step 27: f(x)= 0.08946774236935447
# differential_evolution step 28: f(x)= 0.08946774236935447
# differential_evolution step 29: f(x)= 0.08946774236935447
# differential_evolution step 30: f(x)= 0.08946774236935447
# differential_evolution step 31: f(x)= 0.08946774236935447
# differential_evolution step 32: f(x)= 0.08946774236935447
# differential_evolution step 33: f(x)= 0.08946774236935447
# differential_evolution step 34: f(x)= 0.08792822108007951
# differential_evolution step 35: f(x)= 0.08094634369444266
# differential_evolution step 36: f(x)= 0.08094634369444266
# differential_evolution step 37: f(x)= 0.08094634369444266
# differential_evolution step 38: f(x)= 0.08094634369444266
# differential_evolution step 39: f(x)= 0.08094634369444266
# differential_evolution step 40: f(x)= 0.08094634369444266
# differential_evolution step 41: f(x)= 0.08094634369444266
# differential_evolution step 42: f(x)= 0.08094634369444266
# differential_evolution step 43: f(x)= 0.08094634369444266
# differential_evolution step 44: f(x)= 0.08094634369444266
# differential_evolution step 45: f(x)= 0.08094634369444266
# differential_evolution step 46: f(x)= 0.08094634369444266
# differential_evolution step 47: f(x)= 0.08094634369444266
# differential_evolution step 48: f(x)= 0.08094634369444266
# differential_evolution step 49: f(x)= 0.08094634369444266
# differential_evolution step 50: f(x)= 0.08094634369444266
# differential_evolution step 51: f(x)= 0.08094634369444266
# differential_evolution step 52: f(x)= 0.08094634369444266
# differential_evolution step 53: f(x)= 0.08094634369444266
# differential_evolution step 54: f(x)= 0.08094634369444266
# differential_evolution step 55: f(x)= 0.08094634369444266
# differential_evolution step 56: f(x)= 0.08094634369444266
# differential_evolution step 57: f(x)= 0.08094634369444266
# differential_evolution step 58: f(x)= 0.08094634369444266
# differential_evolution step 59: f(x)= 0.08094634369444266
# differential_evolution step 60: f(x)= 0.08094634369444266
# differential_evolution step 61: f(x)= 0.08094634369444266
# differential_evolution step 62: f(x)= 0.08094634369444266
# differential_evolution step 63: f(x)= 0.08094634369444266
# differential_evolution step 64: f(x)= 0.08094634369444266
# differential_evolution step 65: f(x)= 0.08094634369444266
# differential_evolution step 66: f(x)= 0.08094634369444266
# differential_evolution step 67: f(x)= 0.08094634369444266
# differential_evolution step 68: f(x)= 0.08094634369444266
# differential_evolution step 69: f(x)= 0.08094634369444266
# differential_evolution step 70: f(x)= 0.08094634369444266
# differential_evolution step 71: f(x)= 0.08094634369444266
# differential_evolution step 72: f(x)= 0.08094634369444266
# differential_evolution step 73: f(x)= 0.08094634369444266
# differential_evolution step 74: f(x)= 0.08094634369444266
# differential_evolution step 75: f(x)= 0.08094634369444266
# differential_evolution step 76: f(x)= 0.08094634369444266
# differential_evolution step 77: f(x)= 0.08094634369444266
# differential_evolution step 78: f(x)= 0.07843781262355072
# differential_evolution step 79: f(x)= 0.07843781262355072
# differential_evolution step 80: f(x)= 0.07843781262355072
# differential_evolution step 81: f(x)= 0.0780220486401666
# differential_evolution step 82: f(x)= 0.0780220486401666
# differential_evolution step 83: f(x)= 0.0780220486401666
# differential_evolution step 84: f(x)= 0.0780220486401666
# differential_evolution step 85: f(x)= 0.0780220486401666
# differential_evolution step 86: f(x)= 0.0780220486401666
# differential_evolution step 87: f(x)= 0.0780220486401666
# differential_evolution step 88: f(x)= 0.0780220486401666
# differential_evolution step 89: f(x)= 0.0780220486401666
# differential_evolution step 90: f(x)= 0.0780220486401666
# differential_evolution step 91: f(x)= 0.0780220486401666
# differential_evolution step 92: f(x)= 0.0780220486401666
# differential_evolution step 93: f(x)= 0.0780220486401666
# differential_evolution step 94: f(x)= 0.0780220486401666
# differential_evolution step 95: f(x)= 0.0780220486401666
# differential_evolution step 96: f(x)= 0.0780220486401666
# differential_evolution step 97: f(x)= 0.0780220486401666
# differential_evolution step 98: f(x)= 0.0780220486401666
# differential_evolution step 99: f(x)= 0.0780220486401666
# differential_evolution step 100: f(x)= 0.0780220486401666
# differential_evolution step 101: f(x)= 0.0780220486401666
# differential_evolution step 102: f(x)= 0.0780220486401666
# differential_evolution step 103: f(x)= 0.0780220486401666
# differential_evolution step 104: f(x)= 0.0780220486401666
# differential_evolution step 105: f(x)= 0.07794766528326832
# differential_evolution step 106: f(x)= 0.07794766528326832
# differential_evolution step 107: f(x)= 0.07794766528326832
# differential_evolution step 108: f(x)= 0.07794766528326832
# differential_evolution step 109: f(x)= 0.07794766528326832
# differential_evolution step 110: f(x)= 0.07794766528326832
# differential_evolution step 111: f(x)= 0.07794766528326832
# differential_evolution step 112: f(x)= 0.07794766528326832
# differential_evolution step 113: f(x)= 0.07794766528326832
# differential_evolution step 114: f(x)= 0.07794766528326832
# differential_evolution step 115: f(x)= 0.07794766528326832
# differential_evolution step 116: f(x)= 0.07794766528326832
# differential_evolution step 117: f(x)= 0.07794766528326832
# differential_evolution step 118: f(x)= 0.07794766528326832
# differential_evolution step 119: f(x)= 0.07794766528326832
# differential_evolution step 120: f(x)= 0.07794766528326832
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=742633, Wed Jan 28 11:22:54 2026)
# Gen 100 Mejor fitness: 0.06944791709735247 Sigma 0.014883254289014049 Restart
# Gen 200 Mejor fitness: 0.06613818591673605 Sigma 0.0064812334810071814 Restart
# Gen 300 Mejor fitness: 0.06427273337198977 Sigma 0.0024246062435088157 Restart
# Gen 400 Mejor fitness: 0.06297803483269591 Sigma 0.0008222677019255876 Restart
# Gen 500 Mejor fitness: 0.06180346117880058 Sigma 0.0003711122174429262 Restart
# Gen 600 Mejor fitness: 0.06208238817689029 Sigma 0.0003516194293087871 Restart
# Gen 700 Mejor fitness: 0.062209841095208405 Sigma 0.0003469613510130859 Restart
# Gen 800 Mejor fitness: 0.06217724544749712 Sigma 0.000261264836379758 Restart
# Gen 900 Mejor fitness: 0.06238648342287128 Sigma 0.0001342833041174874 Restart
# Gen 1000 Mejor fitness: 0.062262923555454895 Sigma 0.00010551213915635781 Restart
# differential_evolution step 1: f(x)= 0.1080602930713035
# differential_evolution step 2: f(x)= 0.1080602930713035
# differential_evolution step 3: f(x)= 0.1080602930713035
# differential_evolution step 4: f(x)= 0.1080602930713035
# differential_evolution step 5: f(x)= 0.1080602930713035
# differential_evolution step 6: f(x)= 0.1080602930713035
# differential_evolution step 7: f(x)= 0.1080602930713035
# differential_evolution step 8: f(x)= 0.1044698278056936
# differential_evolution step 9: f(x)= 0.1044698278056936
# differential_evolution step 10: f(x)= 0.1044698278056936
# differential_evolution step 11: f(x)= 0.10157618923105048
# differential_evolution step 12: f(x)= 0.10157618923105048
# differential_evolution step 13: f(x)= 0.10157618923105048
# differential_evolution step 14: f(x)= 0.09951220448100093
# differential_evolution step 15: f(x)= 0.09951220448100093
# differential_evolution step 16: f(x)= 0.09951220448100093
# differential_evolution step 17: f(x)= 0.09951220448100093
# differential_evolution step 18: f(x)= 0.09951220448100093
# differential_evolution step 19: f(x)= 0.09951220448100093
# differential_evolution step 20: f(x)= 0.09951220448100093
# differential_evolution step 21: f(x)= 0.09778483587953339
# differential_evolution step 22: f(x)= 0.09778483587953339
# differential_evolution step 23: f(x)= 0.09778483587953339
# differential_evolution step 24: f(x)= 0.09778483587953339
# differential_evolution step 25: f(x)= 0.09778483587953339
# differential_evolution step 26: f(x)= 0.09674857374317537
# differential_evolution step 27: f(x)= 0.09674857374317537
# differential_evolution step 28: f(x)= 0.09674857374317537
# differential_evolution step 29: f(x)= 0.09674857374317537
# differential_evolution step 30: f(x)= 0.09674857374317537
# differential_evolution step 31: f(x)= 0.09674857374317537
# differential_evolution step 32: f(x)= 0.09674857374317537
# differential_evolution step 33: f(x)= 0.09674857374317537
# differential_evolution step 34: f(x)= 0.09674857374317537
# differential_evolution step 35: f(x)= 0.09674857374317537
# differential_evolution step 36: f(x)= 0.0921869857272744
# differential_evolution step 37: f(x)= 0.0921869857272744
# differential_evolution step 38: f(x)= 0.0921869857272744
# differential_evolution step 39: f(x)= 0.0921869857272744
# differential_evolution step 40: f(x)= 0.0921869857272744
# differential_evolution step 41: f(x)= 0.08734779684747873
# differential_evolution step 42: f(x)= 0.08734779684747873
# differential_evolution step 43: f(x)= 0.08734779684747873
# differential_evolution step 44: f(x)= 0.08734779684747873
# differential_evolution step 45: f(x)= 0.08734779684747873
# differential_evolution step 46: f(x)= 0.08734779684747873
# differential_evolution step 47: f(x)= 0.08734779684747873
# differential_evolution step 48: f(x)= 0.08734779684747873
# differential_evolution step 49: f(x)= 0.08734779684747873
# differential_evolution step 50: f(x)= 0.08734779684747873
# differential_evolution step 51: f(x)= 0.08734779684747873
# differential_evolution step 52: f(x)= 0.08734779684747873
# differential_evolution step 53: f(x)= 0.08734779684747873
# differential_evolution step 54: f(x)= 0.08734779684747873
# differential_evolution step 55: f(x)= 0.08734779684747873
# differential_evolution step 56: f(x)= 0.08734779684747873
# differential_evolution step 57: f(x)= 0.08734779684747873
# differential_evolution step 58: f(x)= 0.08734779684747873
# differential_evolution step 59: f(x)= 0.08734779684747873
# differential_evolution step 60: f(x)= 0.08734779684747873
# differential_evolution step 61: f(x)= 0.08734779684747873
# differential_evolution step 62: f(x)= 0.08734779684747873
# differential_evolution step 63: f(x)= 0.08734779684747873
# differential_evolution step 64: f(x)= 0.08734779684747873
# differential_evolution step 65: f(x)= 0.07425333947370828
# differential_evolution step 66: f(x)= 0.07425333947370828
# differential_evolution step 67: f(x)= 0.07425333947370828
# differential_evolution step 68: f(x)= 0.07425333947370828
# differential_evolution step 69: f(x)= 0.07425333947370828
# differential_evolution step 70: f(x)= 0.07425333947370828
# differential_evolution step 71: f(x)= 0.07425333947370828
# differential_evolution step 72: f(x)= 0.07425333947370828
# differential_evolution step 73: f(x)= 0.07425333947370828
# differential_evolution step 74: f(x)= 0.07425333947370828
# differential_evolution step 75: f(x)= 0.07425333947370828
# differential_evolution step 76: f(x)= 0.07425333947370828
# differential_evolution step 77: f(x)= 0.07425333947370828
# differential_evolution step 78: f(x)= 0.07425333947370828
# differential_evolution step 79: f(x)= 0.07425333947370828
# differential_evolution step 80: f(x)= 0.07425333947370828
# differential_evolution step 81: f(x)= 0.07425333947370828
# differential_evolution step 82: f(x)= 0.07425333947370828
# differential_evolution step 83: f(x)= 0.07425333947370828
# differential_evolution step 84: f(x)= 0.07425333947370828
# differential_evolution step 85: f(x)= 0.07425333947370828
# differential_evolution step 86: f(x)= 0.07425333947370828
# differential_evolution step 87: f(x)= 0.07425333947370828
# differential_evolution step 88: f(x)= 0.07425333947370828
# differential_evolution step 89: f(x)= 0.07425333947370828
# differential_evolution step 90: f(x)= 0.07425333947370828
# differential_evolution step 91: f(x)= 0.07425333947370828
# differential_evolution step 92: f(x)= 0.07425333947370828
# differential_evolution step 93: f(x)= 0.07425333947370828
# differential_evolution step 94: f(x)= 0.07425333947370828
# differential_evolution step 95: f(x)= 0.07425333947370828
# differential_evolution step 96: f(x)= 0.07425333947370828
# differential_evolution step 97: f(x)= 0.07425333947370828
# differential_evolution step 98: f(x)= 0.07425333947370828
# differential_evolution step 99: f(x)= 0.07425333947370828
# differential_evolution step 100: f(x)= 0.07425333947370828
# differential_evolution step 101: f(x)= 0.07425333947370828
# differential_evolution step 102: f(x)= 0.07425333947370828
# differential_evolution step 103: f(x)= 0.07425333947370828
# differential_evolution step 104: f(x)= 0.07425333947370828
# differential_evolution step 105: f(x)= 0.07425333947370828
# differential_evolution step 106: f(x)= 0.07425333947370828
# differential_evolution step 107: f(x)= 0.07425333947370828
# differential_evolution step 108: f(x)= 0.07425333947370828
# differential_evolution step 109: f(x)= 0.07425333947370828
# differential_evolution step 110: f(x)= 0.07425333947370828
# differential_evolution step 111: f(x)= 0.07425333947370828
# differential_evolution step 112: f(x)= 0.07425333947370828
# differential_evolution step 113: f(x)= 0.07425333947370828
# differential_evolution step 114: f(x)= 0.07425333947370828
# differential_evolution step 115: f(x)= 0.07425333947370828
# differential_evolution step 116: f(x)= 0.07425333947370828
# differential_evolution step 117: f(x)= 0.07425333947370828
# differential_evolution step 118: f(x)= 0.07425333947370828
# differential_evolution step 119: f(x)= 0.07425333947370828
# differential_evolution step 120: f(x)= 0.07425333947370828
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=776574, Wed Jan 28 11:30:22 2026)
# Gen 100 Mejor fitness: 0.07290851586574941 Sigma 0.03703928545819061 Restart
# Gen 200 Mejor fitness: 0.06674097939961703 Sigma 0.009800344189772945 Restart
# Gen 300 Mejor fitness: 0.06607094152109241 Sigma 0.0035710863367720233 Restart
# Gen 400 Mejor fitness: 0.06520059899874975 Sigma 0.0011406531698825335 Restart
# Gen 500 Mejor fitness: 0.06478326373160583 Sigma 0.0009092658198565245 Restart
# Gen 600 Mejor fitness: 0.06468965878612633 Sigma 0.000636556838375566 Restart
# Gen 700 Mejor fitness: 0.06441925506309122 Sigma 0.0003955132226073785 Restart
# Gen 800 Mejor fitness: 0.06516930989522028 Sigma 0.000252959257642685 Restart
# Gen 900 Mejor fitness: 0.06409020356242819 Sigma 0.00018905504895583777 Restart
# Gen 1000 Mejor fitness: 0.0639179350346227 Sigma 0.00018189518632491544 Restart
# differential_evolution step 1: f(x)= 0.1185452291497491
# differential_evolution step 2: f(x)= 0.11742220980131887
# differential_evolution step 3: f(x)= 0.10789528919079165
# differential_evolution step 4: f(x)= 0.10789528919079165
# differential_evolution step 5: f(x)= 0.10789528919079165
# differential_evolution step 6: f(x)= 0.10789528919079165
# differential_evolution step 7: f(x)= 0.10789528919079165
# differential_evolution step 8: f(x)= 0.10789528919079165
# differential_evolution step 9: f(x)= 0.10789528919079165
# differential_evolution step 10: f(x)= 0.10789528919079165
# differential_evolution step 11: f(x)= 0.10664833184499958
# differential_evolution step 12: f(x)= 0.10664833184499958
# differential_evolution step 13: f(x)= 0.10664833184499958
# differential_evolution step 14: f(x)= 0.10664833184499958
# differential_evolution step 15: f(x)= 0.10664833184499958
# differential_evolution step 16: f(x)= 0.10664833184499958
# differential_evolution step 17: f(x)= 0.10664833184499958
# differential_evolution step 18: f(x)= 0.10664833184499958
# differential_evolution step 19: f(x)= 0.10664833184499958
# differential_evolution step 20: f(x)= 0.10664833184499958
# differential_evolution step 21: f(x)= 0.10148246820400153
# differential_evolution step 22: f(x)= 0.10148246820400153
# differential_evolution step 23: f(x)= 0.10148246820400153
# differential_evolution step 24: f(x)= 0.10148246820400153
# differential_evolution step 25: f(x)= 0.10148246820400153
# differential_evolution step 26: f(x)= 0.10148246820400153
# differential_evolution step 27: f(x)= 0.10148246820400153
# differential_evolution step 28: f(x)= 0.10148246820400153
# differential_evolution step 29: f(x)= 0.10148246820400153
# differential_evolution step 30: f(x)= 0.10148246820400153
# differential_evolution step 31: f(x)= 0.10148246820400153
# differential_evolution step 32: f(x)= 0.09493525628852748
# differential_evolution step 33: f(x)= 0.09493525628852748
# differential_evolution step 34: f(x)= 0.09493525628852748
# differential_evolution step 35: f(x)= 0.09493525628852748
# differential_evolution step 36: f(x)= 0.09493525628852748
# differential_evolution step 37: f(x)= 0.09493525628852748
# differential_evolution step 38: f(x)= 0.09493525628852748
# differential_evolution step 39: f(x)= 0.09493525628852748
# differential_evolution step 40: f(x)= 0.09493525628852748
# differential_evolution step 41: f(x)= 0.09493525628852748
# differential_evolution step 42: f(x)= 0.09493525628852748
# differential_evolution step 43: f(x)= 0.09493525628852748
# differential_evolution step 44: f(x)= 0.09493525628852748
# differential_evolution step 45: f(x)= 0.09493525628852748
# differential_evolution step 46: f(x)= 0.09493525628852748
# differential_evolution step 47: f(x)= 0.09493525628852748
# differential_evolution step 48: f(x)= 0.09493525628852748
# differential_evolution step 49: f(x)= 0.09493525628852748
# differential_evolution step 50: f(x)= 0.09493525628852748
# differential_evolution step 51: f(x)= 0.09493525628852748
# differential_evolution step 52: f(x)= 0.09493525628852748
# differential_evolution step 53: f(x)= 0.09493525628852748
# differential_evolution step 54: f(x)= 0.09493525628852748
# differential_evolution step 55: f(x)= 0.09493525628852748
# differential_evolution step 56: f(x)= 0.09493525628852748
# differential_evolution step 57: f(x)= 0.09493525628852748
# differential_evolution step 58: f(x)= 0.09493525628852748
# differential_evolution step 59: f(x)= 0.09493525628852748
# differential_evolution step 60: f(x)= 0.09493525628852748
# differential_evolution step 61: f(x)= 0.09493525628852748
# differential_evolution step 62: f(x)= 0.09308605282993555
# differential_evolution step 63: f(x)= 0.09308605282993555
# differential_evolution step 64: f(x)= 0.08825661476954591
# differential_evolution step 65: f(x)= 0.08825661476954591
# differential_evolution step 66: f(x)= 0.08825661476954591
# differential_evolution step 67: f(x)= 0.08825661476954591
# differential_evolution step 68: f(x)= 0.08825661476954591
# differential_evolution step 69: f(x)= 0.08825661476954591
# differential_evolution step 70: f(x)= 0.08825661476954591
# differential_evolution step 71: f(x)= 0.08825661476954591
# differential_evolution step 72: f(x)= 0.08825661476954591
# differential_evolution step 73: f(x)= 0.08825661476954591
# differential_evolution step 74: f(x)= 0.08825661476954591
# differential_evolution step 75: f(x)= 0.08825661476954591
# differential_evolution step 76: f(x)= 0.08825661476954591
# differential_evolution step 77: f(x)= 0.08825661476954591
# differential_evolution step 78: f(x)= 0.08825661476954591
# differential_evolution step 79: f(x)= 0.08825661476954591
# differential_evolution step 80: f(x)= 0.08825661476954591
# differential_evolution step 81: f(x)= 0.08825661476954591
# differential_evolution step 82: f(x)= 0.08825661476954591
# differential_evolution step 83: f(x)= 0.08825661476954591
# differential_evolution step 84: f(x)= 0.08825661476954591
# differential_evolution step 85: f(x)= 0.08825661476954591
# differential_evolution step 86: f(x)= 0.08825661476954591
# differential_evolution step 87: f(x)= 0.08825661476954591
# differential_evolution step 88: f(x)= 0.08825661476954591
# differential_evolution step 89: f(x)= 0.08825661476954591
# differential_evolution step 90: f(x)= 0.08825661476954591
# differential_evolution step 91: f(x)= 0.08825661476954591
# differential_evolution step 92: f(x)= 0.08825661476954591
# differential_evolution step 93: f(x)= 0.08825661476954591
# differential_evolution step 94: f(x)= 0.08825661476954591
# differential_evolution step 95: f(x)= 0.08825661476954591
# differential_evolution step 96: f(x)= 0.08825661476954591
# differential_evolution step 97: f(x)= 0.08825661476954591
# differential_evolution step 98: f(x)= 0.08825661476954591
# differential_evolution step 99: f(x)= 0.08825661476954591
# differential_evolution step 100: f(x)= 0.08825661476954591
# differential_evolution step 101: f(x)= 0.08825661476954591
# differential_evolution step 102: f(x)= 0.08825661476954591
# differential_evolution step 103: f(x)= 0.08825661476954591
# differential_evolution step 104: f(x)= 0.08825661476954591
# differential_evolution step 105: f(x)= 0.08825661476954591
# differential_evolution step 106: f(x)= 0.08825661476954591
# differential_evolution step 107: f(x)= 0.08825661476954591
# differential_evolution step 108: f(x)= 0.08825661476954591
# differential_evolution step 109: f(x)= 0.08825661476954591
# differential_evolution step 110: f(x)= 0.08825661476954591
# differential_evolution step 111: f(x)= 0.08825661476954591
# differential_evolution step 112: f(x)= 0.08825661476954591
# differential_evolution step 113: f(x)= 0.08825661476954591
# differential_evolution step 114: f(x)= 0.08825661476954591
# differential_evolution step 115: f(x)= 0.08825661476954591
# differential_evolution step 116: f(x)= 0.08825661476954591
# differential_evolution step 117: f(x)= 0.08825661476954591
# differential_evolution step 118: f(x)= 0.08817445233646477
# differential_evolution step 119: f(x)= 0.08817445233646477
# differential_evolution step 120: f(x)= 0.08817445233646477
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=698378, Wed Jan 28 11:36:02 2026)
# Gen 100 Mejor fitness: 0.08673582158805572 Sigma 0.02489920034958329 Restart
# Gen 200 Mejor fitness: 0.07424547937306322 Sigma 0.0119989173470076 Restart
# Gen 300 Mejor fitness: 0.06979236361113102 Sigma 0.011977411302591149 Restart
# Gen 400 Mejor fitness: 0.06746327134496674 Sigma 0.005030748749985283 Restart
# Gen 500 Mejor fitness: 0.06612846606290423 Sigma 0.002117214549227638 Restart
# Gen 600 Mejor fitness: 0.06488541143434602 Sigma 0.000873853875219159 Restart
# Gen 700 Mejor fitness: 0.06584231656463368 Sigma 0.0008038246202368984 Restart
# Gen 800 Mejor fitness: 0.06517172699046121 Sigma 0.000619940878425178 Restart
# Gen 900 Mejor fitness: 0.06573490319423626 Sigma 0.0006489359944567142 Restart
# Gen 1000 Mejor fitness: 0.06568561937989643 Sigma 0.0007108899536300261 Restart

# %%
predicted_joined_audio = []

for preset, duration in estimated_presets:
    preset = np.expand_dims(preset, axis=0)
    # error = evaluate_presets((denormalize_preset(from_matrix_to_preset(preset)), target_C, duration))
    # print('Error', error)
    # target_audio = np.expand_dims(audio_segments[0], axis=0)
    predicted_audio = render_presets(denormalize_preset(from_matrix_to_preset(preset)), duration)
    predicted_joined_audio.append(predicted_audio[0])

    denormalized_predicted_preset = denormalize_preset(from_matrix_to_preset(preset))
    pretty_print(denormalized_predicted_preset)

predicted_joined_audio = np.concatenate(predicted_joined_audio, axis=0)
# Out:
# {
#   osc1_shape:   [
#     2.453805498729112
#   ]
#   osc1_phase:   [
#     0.24138269061391615
#   ]
#   osc1_volume:   [
#     0.16669368210003774
#   ]
#   osc1_freq:   [
#     10961.57304877417
#   ]
#   osc2_shape:   [
#     1.9722550785355255
#   ]
#   osc2_phase:   [
#     0.15257068328515197
#   ]
#   osc2_volume:   [
#     0.9564625337406583
#   ]
#   osc2_freq:   [
#     2613.372534196738
#   ]
#   osc3_shape:   [
#     2.7492168872351996
#   ]
#   osc3_phase:   [
#     0.8863984311144519
#   ]
#   osc3_volume:   [
#     0.15892797190595126
#   ]
#   osc3_freq:   [
#     549.67592028131
#   ]
#   osc4_shape:   [
#     3.120076236071399
#   ]
#   osc4_phase:   [
#     0.011729935671446892
#   ]
#   osc4_volume:   [
#     0.4459051810999014
#   ]
#   osc4_freq:   [
#     521.811089573925
#   ]
#   oscnoise_volume:   [
#     0.7605483598449564
#   ]
#   filter_envelope_attack:   [
#     0.2592694046986112
#   ]
#   filter_envelope_decay:   [
#     0.4492192906458202
#   ]
#   filter_envelope_sustain:   [
#     0.3615896874800507
#   ]
#   filter_envelope_release:   [
#     0.21916689308204906
#   ]
#   base_cutoff_hz:   [
#     187.15933499626203
#   ]
#   filter_type:   [
#     1.9996241207689929
#   ]
#   base_q:   [
#     2.8947177746354837
#   ]
#   envelope_depth:   [
#     0.316286492464682
#   ]
#   envelope_attack:   [
#     0.027246052099239644
#   ]
#   envelope_decay:   [
#     0.18909060787408685
#   ]
#   envelope_sustain:   [
#     0.17150756757209132
#   ]
#   envelope_release:   [
#     0.0003331937458633649
#   ]
# }
# {
#   osc1_shape:   [
#     0.3252772604468166
#   ]
#   osc1_phase:   [
#     0.6338872952448537
#   ]
#   osc1_volume:   [
#     0.47263390787204806
#   ]
#   osc1_freq:   [
#     2595.652285463125
#   ]
#   osc2_shape:   [
#     1.6518867599331009
#   ]
#   osc2_phase:   [
#     0.08976349632016534
#   ]
#   osc2_volume:   [
#     0.1345298365722084
#   ]
#   osc2_freq:   [
#     2279.7304399108875
#   ]
#   osc3_shape:   [
#     1.9463442064906233
#   ]
#   osc3_phase:   [
#     0.16764474114167524
#   ]
#   osc3_volume:   [
#     0.15451139232303854
#   ]
#   osc3_freq:   [
#     9196.513143881186
#   ]
#   osc4_shape:   [
#     1.6402293462595023
#   ]
#   osc4_phase:   [
#     0.26650798983930163
#   ]
#   osc4_volume:   [
#     0.9239763790738105
#   ]
#   osc4_freq:   [
#     523.4381603556095
#   ]
#   oscnoise_volume:   [
#     0.33671877360656943
#   ]
#   filter_envelope_attack:   [
#     0.005137782989445041
#   ]
#   filter_envelope_decay:   [
#     0.5440716222165983
#   ]
#   filter_envelope_sustain:   [
#     0.9976393491178394
#   ]
#   filter_envelope_release:   [
#     0.33737171271971844
#   ]
#   base_cutoff_hz:   [
#     276.2067369676324
#   ]
#   filter_type:   [
#     1.9951513165669343
#   ]
#   base_q:   [
#     7.276620403685888
#   ]
#   envelope_depth:   [
#     0.003150173916499767
#   ]
#   envelope_attack:   [
#     0.18894275153482515
#   ]
#   envelope_decay:   [
#     0.1664391609221612
#   ]
#   envelope_sustain:   [
#     0.7389194721173227
#   ]
#   envelope_release:   [
#     0.31702648473587186
#   ]
# }
# {
#   osc1_shape:   [
#     2.391780220615074
#   ]
#   osc1_phase:   [
#     0.35197640172848255
#   ]
#   osc1_volume:   [
#     0.970451949860098
#   ]
#   osc1_freq:   [
#     785.1965630086542
#   ]
#   osc2_shape:   [
#     0.9114119854981936
#   ]
#   osc2_phase:   [
#     0.9966545166078522
#   ]
#   osc2_volume:   [
#     0.939157759616085
#   ]
#   osc2_freq:   [
#     2405.1989162764567
#   ]
#   osc3_shape:   [
#     0.29233413237532224
#   ]
#   osc3_phase:   [
#     0.31185910205490236
#   ]
#   osc3_volume:   [
#     0.6704729359683523
#   ]
#   osc3_freq:   [
#     15666.89297505475
#   ]
#   osc4_shape:   [
#     0.3769287995607099
#   ]
#   osc4_phase:   [
#     0.9830330697251904
#   ]
#   osc4_volume:   [
#     0.2310095471356643
#   ]
#   osc4_freq:   [
#     237.82560079215054
#   ]
#   oscnoise_volume:   [
#     0.3805272697582744
#   ]
#   filter_envelope_attack:   [
#     0.34112469259376943
#   ]
#   filter_envelope_decay:   [
#     0.4994879782988243
#   ]
#   filter_envelope_sustain:   [
#     0.7030282635348253
#   ]
#   filter_envelope_release:   [
#     0.39735892040603443
#   ]
#   base_cutoff_hz:   [
#     334.6475575439599
#   ]
#   filter_type:   [
#     1.8435638542002963
#   ]
#   base_q:   [
#     16.400155895747776
#   ]
#   envelope_depth:   [
#     0.014392286331011825
#   ]
#   envelope_attack:   [
#     0.10782145227328266
#   ]
#   envelope_decay:   [
#     0.22666690874180373
#   ]
#   envelope_sustain:   [
#     0.48089425945433556
#   ]
#   envelope_release:   [
#     0.033541299634174286
#   ]
# }

# %%
spect = evaluate_target(np.array([audio]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(audio, rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spect = evaluate_target(np.array([predicted_joined_audio]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(predicted_joined_audio, rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
