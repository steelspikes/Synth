# %%
import os

# Subir un nivel respecto a la carpeta actual
os.chdir("..")

import numpy as np
from globals import SAMPLE_RATE, PROCESSORS
import librosa
import matplotlib.pyplot as plt
from IPython.display import Audio, display
from scipy.signal import find_peaks

from Utils import load_parameters_file, from_matrix_to_preset, MSE, denormalize_preset, normalize_preset, pretty_print, PARAM_NAMES, from_preset_to_matrix, mel_spectrogram, mfcc, spectrogram
from Synth import Synth
import numpy as np
import cma
import matplotlib.pyplot as plt
from multiprocessing import Pool
from parallelEvaluation import evaluate_presets
from scipy.optimize import differential_evolution

# %%
def get_audio(audio_path):
    y, _sr = librosa.load(audio_path, sr=SAMPLE_RATE)
    y = np.array(y, dtype=np.float64)
    y, _ = librosa.effects.trim(y, top_db=15)

    rms_target = 0.1
    rms_actual = np.sqrt(np.mean(y**2))
    scale = rms_target / (rms_actual + 1e-8)
    return y * scale

def split_audio(audio, prominence=0.01):
    win_size = int(0.02 * SAMPLE_RATE)

    rectified_signal = np.abs(audio)
    window = np.ones(win_size) / win_size
    envelope = np.convolve(rectified_signal, window, mode='same')

    minimals, _ = find_peaks(-envelope, prominence=prominence)
    minimals = np.concatenate((np.array([0]), minimals))

    minimals = minimals + (win_size // 2)

    audios = []
    
    for i in range(minimals.shape[0]):
        if i < minimals.shape[0] - 1:
            audios.append(audio[minimals[i] : minimals[i+1]])
        else:
            audios.append(audio[minimals[i]:])

    return audios

# %%
def render_presets(presets, duration=0):
    synth = Synth(
        sample_rate=SAMPLE_RATE,
        duration=duration,
        presets=presets
    )
    return synth.process_audio().astype(np.float64)

def evaluate_target(audio):
    return mel_spectrogram(audio, sr=SAMPLE_RATE, n_fft=2048, hop_length=256, n_mels=128)

# %%
def search_with_DE(target_C, duration):
    bounds = [(0, 1)] * len(PARAM_NAMES)

    with Pool(PROCESSORS) as pool:
        def get_fitness(solutions):
            solutions = np.array(solutions).T
            solutions_splitted = np.array_split(solutions, PROCESSORS)
            presets_splitted = [(denormalize_preset(from_matrix_to_preset(chunk)), target_C, duration) for chunk in solutions_splitted]
            
            solutions_evaluated = pool.map(evaluate_presets, presets_splitted)
            return np.concatenate(solutions_evaluated).tolist()
            
        result = differential_evolution(
            get_fitness,
            bounds=bounds,
            popsize=10,        # 10 × n_params individuos
            mutation=(0.5, 1),
            recombination=0.7,
            tol=1e-4,
            maxiter=120,
            polish=False,
            seed=None,
            disp=True,
            workers=1,
            vectorized=True
        )

        x_best = result.x
        f_best = result.fun

        return x_best

# %%
def search_with_CMA(target_C, duration, x0):
    sigma0 = 0.1

    with Pool(PROCESSORS) as pool:
        def get_fitness(solutions):
            solutions = np.array(solutions)
            solutions_splitted = np.array_split(solutions, PROCESSORS)
            presets_splitted = [(denormalize_preset(from_matrix_to_preset(chunk)), target_C, duration) for chunk in solutions_splitted]
            
            solutions_evaluated = pool.map(evaluate_presets, presets_splitted)
            return np.concatenate(solutions_evaluated)

        options = {
            'popsize': 30,
            'bounds': [np.zeros_like(x0), np.ones_like(x0)],
            'tolfun': 1e-8,
            'tolx': 1e-8,
            'maxiter': 1000
        }

        es = cma.CMAEvolutionStrategy(x0, sigma0, options)
        gen = 1

        while not es.stop():
            solutions = np.array(es.ask())  # devuelve una lista de individuos

            fitnesses = get_fitness(solutions)

            best_idx = np.argmin(fitnesses)          # índice del mejor fitness
            best_fitness = fitnesses[best_idx]       # fitness correspondiente

            if gen % 100 == 0:
                print("Gen", gen, "Mejor fitness:", best_fitness, "Sigma", es.sigma, "Restart")

            es.tell(solutions, fitnesses)  # pasar fitness al algoritmo

            gen += 1

        return es.best

# %%
audio_path = 'C:/Users/bryan/Documents/GitHub/Synth/exports/Violin_target.wav'
audio = get_audio(audio_path) # Quitar esto

plt.plot(audio)
plt.show()
Audio(audio, rate=SAMPLE_RATE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_segments = split_audio(audio, prominence=0.09)

for audio_segment in audio_segments:
    plt.plot(audio_segment)
    plt.show()
    display(Audio(audio_segment, rate=SAMPLE_RATE))

print('Pieces', len(audio_segments))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Pieces 1

# %%
estimated_presets = []

if __name__ == '__main__':
    for audio_segment in [audio_segments[0]]:
        target_C = evaluate_target(np.expand_dims(audio_segment, axis=0))
        duration = len(audio_segment) / SAMPLE_RATE
        best = search_with_DE(target_C, duration)
        best = search_with_CMA(target_C, duration, best)
        estimated_presets.append((best.x, duration))
# Out:
# c:\Users\bryan\Documents\GitHub\Synth\venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:487: UserWarning: differential_evolution: the 'vectorized' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# differential_evolution step 1: f(x)= 0.19323647944782602
# differential_evolution step 2: f(x)= 0.19323647944782602
# differential_evolution step 3: f(x)= 0.18864250422660692
# differential_evolution step 4: f(x)= 0.1816171893802609
# differential_evolution step 5: f(x)= 0.1816171893802609
# differential_evolution step 6: f(x)= 0.1816171893802609
# differential_evolution step 7: f(x)= 0.17369950298538633
# differential_evolution step 8: f(x)= 0.17369950298538633
# differential_evolution step 9: f(x)= 0.17369950298538633
# differential_evolution step 10: f(x)= 0.17369950298538633
# differential_evolution step 11: f(x)= 0.17369950298538633
# differential_evolution step 12: f(x)= 0.17369950298538633
# differential_evolution step 13: f(x)= 0.17196329364798343
# differential_evolution step 14: f(x)= 0.17196329364798343
# differential_evolution step 15: f(x)= 0.17196329364798343
# differential_evolution step 16: f(x)= 0.15409152508813329
# differential_evolution step 17: f(x)= 0.15409152508813329
# differential_evolution step 18: f(x)= 0.15409152508813329
# differential_evolution step 19: f(x)= 0.15409152508813329
# differential_evolution step 20: f(x)= 0.15409152508813329
# differential_evolution step 21: f(x)= 0.15409152508813329
# differential_evolution step 22: f(x)= 0.15409152508813329
# differential_evolution step 23: f(x)= 0.14975631257825062
# differential_evolution step 24: f(x)= 0.14975631257825062
# differential_evolution step 25: f(x)= 0.14975631257825062
# differential_evolution step 26: f(x)= 0.14975631257825062
# differential_evolution step 27: f(x)= 0.14975631257825062
# differential_evolution step 28: f(x)= 0.14975631257825062
# differential_evolution step 29: f(x)= 0.14975631257825062
# differential_evolution step 30: f(x)= 0.14975631257825062
# differential_evolution step 31: f(x)= 0.14975631257825062
# differential_evolution step 32: f(x)= 0.14975631257825062
# differential_evolution step 33: f(x)= 0.14975631257825062
# differential_evolution step 34: f(x)= 0.14975631257825062
# differential_evolution step 35: f(x)= 0.14975631257825062
# differential_evolution step 36: f(x)= 0.14975631257825062
# differential_evolution step 37: f(x)= 0.14975631257825062
# differential_evolution step 38: f(x)= 0.14975631257825062
# differential_evolution step 39: f(x)= 0.1400237228003434
# differential_evolution step 40: f(x)= 0.1400237228003434
# differential_evolution step 41: f(x)= 0.1400237228003434
# differential_evolution step 42: f(x)= 0.1340967762297344
# differential_evolution step 43: f(x)= 0.1340967762297344
# differential_evolution step 44: f(x)= 0.1340967762297344
# differential_evolution step 45: f(x)= 0.1340967762297344
# differential_evolution step 46: f(x)= 0.1340967762297344
# differential_evolution step 47: f(x)= 0.1340967762297344
# differential_evolution step 48: f(x)= 0.1340967762297344
# differential_evolution step 49: f(x)= 0.13339367091261833
# differential_evolution step 50: f(x)= 0.13339367091261833
# differential_evolution step 51: f(x)= 0.13339367091261833
# differential_evolution step 52: f(x)= 0.13339367091261833
# differential_evolution step 53: f(x)= 0.13339367091261833
# differential_evolution step 54: f(x)= 0.13339367091261833
# differential_evolution step 55: f(x)= 0.13339367091261833
# differential_evolution step 56: f(x)= 0.13339367091261833
# differential_evolution step 57: f(x)= 0.13339367091261833
# differential_evolution step 58: f(x)= 0.13068705613019865
# differential_evolution step 59: f(x)= 0.13068705613019865
# differential_evolution step 60: f(x)= 0.12845738687329858
# differential_evolution step 61: f(x)= 0.12845738687329858
# differential_evolution step 62: f(x)= 0.12845738687329858
# differential_evolution step 63: f(x)= 0.12845738687329858
# differential_evolution step 64: f(x)= 0.12582534796292455
# differential_evolution step 65: f(x)= 0.12582534796292455
# differential_evolution step 66: f(x)= 0.12582534796292455
# differential_evolution step 67: f(x)= 0.12145751469862298
# differential_evolution step 68: f(x)= 0.11645103219302307
# differential_evolution step 69: f(x)= 0.11645103219302307
# differential_evolution step 70: f(x)= 0.11645103219302307
# differential_evolution step 71: f(x)= 0.11645103219302307
# differential_evolution step 72: f(x)= 0.11645103219302307
# differential_evolution step 73: f(x)= 0.11645103219302307
# differential_evolution step 74: f(x)= 0.11645103219302307
# differential_evolution step 75: f(x)= 0.11645103219302307
# differential_evolution step 76: f(x)= 0.11645103219302307
# differential_evolution step 77: f(x)= 0.11645103219302307
# differential_evolution step 78: f(x)= 0.11645103219302307
# differential_evolution step 79: f(x)= 0.11645103219302307
# differential_evolution step 80: f(x)= 0.11645103219302307
# differential_evolution step 81: f(x)= 0.11645103219302307
# differential_evolution step 82: f(x)= 0.11645103219302307
# differential_evolution step 83: f(x)= 0.11645103219302307
# differential_evolution step 84: f(x)= 0.11645103219302307
# differential_evolution step 85: f(x)= 0.11645103219302307
# differential_evolution step 86: f(x)= 0.11645103219302307
# differential_evolution step 87: f(x)= 0.11645103219302307
# differential_evolution step 88: f(x)= 0.11645103219302307
# differential_evolution step 89: f(x)= 0.11645103219302307
# differential_evolution step 90: f(x)= 0.11627294721140714
# differential_evolution step 91: f(x)= 0.11627294721140714
# differential_evolution step 92: f(x)= 0.11627294721140714
# differential_evolution step 93: f(x)= 0.11627294721140714
# differential_evolution step 94: f(x)= 0.11627294721140714
# differential_evolution step 95: f(x)= 0.11627294721140714
# differential_evolution step 96: f(x)= 0.11525986756259275
# differential_evolution step 97: f(x)= 0.11525986756259275
# differential_evolution step 98: f(x)= 0.11525986756259275
# differential_evolution step 99: f(x)= 0.11525986756259275
# differential_evolution step 100: f(x)= 0.11525986756259275
# differential_evolution step 101: f(x)= 0.11525986756259275
# differential_evolution step 102: f(x)= 0.11525986756259275
# differential_evolution step 103: f(x)= 0.11525986756259275
# differential_evolution step 104: f(x)= 0.11525986756259275
# differential_evolution step 105: f(x)= 0.11525986756259275
# differential_evolution step 106: f(x)= 0.11525986756259275
# differential_evolution step 107: f(x)= 0.11525986756259275
# differential_evolution step 108: f(x)= 0.11525986756259275
# differential_evolution step 109: f(x)= 0.11525986756259275
# differential_evolution step 110: f(x)= 0.11525986756259275
# differential_evolution step 111: f(x)= 0.11525986756259275
# differential_evolution step 112: f(x)= 0.11525986756259275
# differential_evolution step 113: f(x)= 0.11525986756259275
# differential_evolution step 114: f(x)= 0.11525986756259275
# differential_evolution step 115: f(x)= 0.11525986756259275
# differential_evolution step 116: f(x)= 0.11525986756259275
# differential_evolution step 117: f(x)= 0.11525986756259275
# differential_evolution step 118: f(x)= 0.11129705336335335
# differential_evolution step 119: f(x)= 0.10836119673617745
# differential_evolution step 120: f(x)= 0.10836119673617745
# (15_w,30)-aCMA-ES (mu_w=8.6,w_1=20%) in dimension 29 (seed=774127, Wed Jan 28 08:18:05 2026)
# Gen 100 Mejor fitness: 0.14719820926354157 Sigma 0.0435220497584241 Restart
# Gen 200 Mejor fitness: 0.11129003066332266 Sigma 0.020126401529587196 Restart
# Gen 300 Mejor fitness: 0.10129228143687714 Sigma 0.015247838187358805 Restart
# Gen 400 Mejor fitness: 0.09911659392162898 Sigma 0.009720700642595415 Restart
# Gen 500 Mejor fitness: 0.09695269582300219 Sigma 0.013408031416954586 Restart
# Gen 600 Mejor fitness: 0.07225827013762309 Sigma 0.019165666353920106 Restart
# Gen 700 Mejor fitness: 0.06802261345177929 Sigma 0.008282374686982626 Restart
# NOTE (module=cma, iteration=701):
# condition in coordinate system exceeded 1.0e+08, rescaled to 1.0e+00,
# condition changed from 2.6e+08 to 4.2e+01
# Gen 800 Mejor fitness: 0.06692519741471818 Sigma 0.0049224070096883 Restart
# Gen 900 Mejor fitness: 0.06599928877271477 Sigma 0.002474301667064931 Restart
# Gen 1000 Mejor fitness: 0.06584639832421374 Sigma 0.0013539033107789753 Restart

# %%
predicted_joined_audio = []

for preset, duration in estimated_presets:
    preset = np.expand_dims(preset, axis=0)
    # error = evaluate_presets((denormalize_preset(from_matrix_to_preset(preset)), target_C, duration))
    # print('Error', error)
    # target_audio = np.expand_dims(audio_segments[0], axis=0)
    predicted_audio = render_presets(denormalize_preset(from_matrix_to_preset(preset)), duration)
    predicted_joined_audio.append(predicted_audio[0])

    denormalized_predicted_preset = denormalize_preset(from_matrix_to_preset(preset))
    pretty_print(denormalized_predicted_preset)

predicted_joined_audio = np.concatenate(predicted_joined_audio, axis=0)
# Out:
# {
#   osc1_shape:   [
#     1.9863362927846666
#   ]
#   osc1_phase:   [
#     0.9999977886453278
#   ]
#   osc1_volume:   [
#     0.9964570839919228
#   ]
#   osc1_freq:   [
#     658.2090070614856
#   ]
#   osc2_shape:   [
#     0.8397488641925116
#   ]
#   osc2_phase:   [
#     0.06466957193415117
#   ]
#   osc2_volume:   [
#     0.0011626221454205596
#   ]
#   osc2_freq:   [
#     1706.5782501305484
#   ]
#   osc3_shape:   [
#     0.32895229700182554
#   ]
#   osc3_phase:   [
#     0.6926317668582026
#   ]
#   osc3_volume:   [
#     0.11082446359377175
#   ]
#   osc3_freq:   [
#     21883.685587307526
#   ]
#   osc4_shape:   [
#     0.6571246124598701
#   ]
#   osc4_phase:   [
#     0.1787532072307436
#   ]
#   osc4_volume:   [
#     0.057289256045768594
#   ]
#   osc4_freq:   [
#     690.1132871521504
#   ]
#   oscnoise_volume:   [
#     0.017509908277856426
#   ]
#   filter_envelope_attack:   [
#     0.48638934502614284
#   ]
#   filter_envelope_decay:   [
#     0.1952109008034954
#   ]
#   filter_envelope_sustain:   [
#     0.4953112015591219
#   ]
#   filter_envelope_release:   [
#     0.17885637253739525
#   ]
#   base_cutoff_hz:   [
#     4070.9842602988315
#   ]
#   filter_type:   [
#     1.426040273287729
#   ]
#   base_q:   [
#     16.266101768989333
#   ]
#   envelope_depth:   [
#     0.01618731992643838
#   ]
#   envelope_attack:   [
#     0.0030054564782747714
#   ]
#   envelope_decay:   [
#     0.006795928285552069
#   ]
#   envelope_sustain:   [
#     0.30629172883574485
#   ]
#   envelope_release:   [
#     0.00035094416561116417
#   ]
# }

# %%
spect = evaluate_target(np.array([audio_segments[0]]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(audio_segments[0], rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spect = evaluate_target(np.array([predicted_joined_audio]))[0]
librosa.display.specshow(spect, sr=SAMPLE_RATE, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma de Mel')
plt.tight_layout()
plt.show()

display(Audio(predicted_joined_audio, rate=SAMPLE_RATE))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
